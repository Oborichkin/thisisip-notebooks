# %%
import re
import json

import requests
from bs4 import BeautifulSoup

from IPython.display import JSON

# %%
document_relationships = {
    "informatively references": {
        "desc": "Informative Reference",
        "inverse": "is informatively referenced by"
    },
    "normatively references": {
        "desc": "Normative Reference",
        "inverse": "is normatively referenced by"
    },
    "Reference": {
        "desc": "A reference found in a document which does not have split normative/informative reference sections",
        "inverse": "Referenced by"
    },
    "Possible Reference": {
        "desc": "Reference of unknown type, likely found in the text of the document",
        "inverse": "Possibly Referenced By"
    }
}

# %%
def _find_by_text(soup, tag, text):
    tags = soup.find_all(tag)
    thetag = None
    for tag in tags:
        if tag.find(text=re.compile(text)):
            thetag = tag
    return thetag

# %%
def parse_page(html):
    soup = BeautifulSoup(html, "html.parser")
    title, rfc_id = list(soup.find("h2").stripped_strings)
    last_updated = soup.find('th', string=re.compile("Last updated")).find_next("td", class_=None).text.strip()

    aka_div = _find_by_text(soup, 'div', "Also known as")
    aka = [{"uri": a.get("href"), "name": a.text} for a in aka_div.find_all("a")] if aka_div else []
    
    updates_div = _find_by_text(soup, 'div', "Updates")
    updates = [{"uri": a.get("href"), "name": a.text} for a in updates_div.find_all("a")] if updates_div else []
    
    updated_by_div = _find_by_text(soup, 'div', "Updated by")
    updated_by = [{"uri": a.get("href"), "name": a.text} for a in updated_by_div.find_all("a")] if updated_by_div else []

    obsoletes_div = _find_by_text(soup, 'div', "Obsoletes")
    obsoletes = [{"uri": a.get("href"), "name": a.text} for a in obsoletes_div.find_all("a")] if obsoletes_div else []
    
    obsoleted_by_div = _find_by_text(soup, 'div', "Obsoleted by")
    obsoleted_by = [{"uri": a.get("href"), "name": a.text} for a in obsoleted_by_div.find_all("a")] if obsoleted_by_div else []
            
    authors = [
        {"email": x.get("href"), "name": x.text}
        for x in soup.find('th', string=re.compile("Author"))
        .find_next("td", class_=None)
        .find_all("a", string=re.compile(".+"))
    ]
    
    return {
        "title": title,
        "text": _find_by_text(soup, 'a', 'plain text').get("href"),
        "pdf": _find_by_text(soup, 'a', 'pdf').get("href"),
        "html": _find_by_text(soup, 'a', 'html').get("href"),
        "label": rfc_id,
        "aka": aka,
        "last_updated": last_updated,
        "updates": updates,
        "updated_by": updated_by,
        "obsoletes": obsoletes,
        "obsoleted_by": obsoleted_by,
        "authors": authors
    }

# %%
def parse_references(html):
    result = []
    soup = BeautifulSoup(html, 'html.parser')
    try:
        rows = soup.find("h1").find_next("table").findAll('tr')[1:]
        for row in rows:
            col = row.find_all("td")
            doc = col[0].text.strip().split("\n")[0]
            status = col[2].text.strip()
            Type = col[3].text.strip()
            downref = col[4].text.strip()
            result.append({
                "name": doc,
                "status": status,
                "type": Type,
                "downref": downref
            })
    except AttributeError:
        pass
    return result

# %%
DATATRACKER_URL = "datatracker.ietf.org"
def get_datatracker_doc_info(uri, url=DATATRACKER_URL):
    r = requests.get(f"https://{url}/doc/{uri}/")
    
    main = parse_page(r.content)

    ref = requests.get(f"https://{url}/doc/{main['label'].lower().replace(' ', '')}/references/")
    refd = requests.get(f"https://{url}/doc/{main['label'].lower().replace(' ', '')}/referencedby/")
    
    main = parse_page(r.content)
    refs = parse_references(ref.content)
    refds = parse_references(refd.content)
    main["references"] = refs
    main["referenced_by"] = refds
    
    return main

# %%
docs = []
parsed = []
to_parse = ["rfc3261"]

# %%
def parse_one(doc):
    print(f"Parsing {doc}")
    if doc in parsed:
        return
    result = get_datatracker_doc_info(doc)
    docs.append(result)
    parsed.append(doc)
    for aka in result["aka"]:
        parsed.append(aka["name"].lower().replace(" ", ""))
    
    for link in [*result["updates"], *result["updated_by"], *result["obsoletes"], *result["obsoleted_by"], *result["references"], *result["referenced_by"]]:
        i = link["name"].lower().replace(" ", "")
        if i not in parsed:
            to_parse.append(i)

# %%
x = 100
while x:
    doc = to_parse.pop(0)
    print(f"Parsing {doc}")
    if doc in parsed:
        continue
    result = get_datatracker_doc_info(doc)
    docs.append(result)
    parsed.append(doc)
    for aka in result["aka"]:
        parsed.append(aka["name"].lower().replace(" ", ""))
    
    for link in [*result["updates"], *result["updated_by"], *result["obsoletes"], *result["obsoleted_by"], *result["references"], *result["referenced_by"]]:
        i = link["name"].lower().replace(" ", "")
        if i not in parsed:
            to_parse.append(i)
    
    x -= 1
# Out:
# Parsing rfc4189
# Parsing rfc4215
# Parsing rfc4235
# Parsing rfc4240
# Parsing rfc4244
# Parsing rfc4245
# Parsing rfc4320
# Parsing rfc4354
# Parsing rfc4376
# Parsing rfc4411
# Parsing rfc4412
# Parsing rfc4453
# Parsing rfc4457
# Parsing rfc4458
# Parsing rfc4474
# Parsing rfc4483
# Parsing rfc4484
# Parsing rfc4485
# Parsing rfc4488
# Parsing rfc4497
# Parsing rfc4508
# Parsing rfc4538
# Parsing rfc4567
# Parsing rfc4569
# Parsing rfc4575
# Parsing rfc4583
# Parsing rfc4590
# Parsing rfc4660
# Parsing rfc4662
# Parsing rfc4722
# Parsing rfc4730
# Parsing rfc4740
# Parsing rfc4759
# Parsing rfc4769
# Parsing rfc4780
# Parsing rfc4825
# Parsing rfc4826
# Parsing rfc4904
# Parsing rfc4916
# Parsing rfc4964
# Parsing rfc4967
# Parsing rfc4975
# Parsing rfc4976
# Parsing rfc5025
# Parsing rfc5027
# Parsing rfc5031
# Parsing rfc5049
# Parsing rfc5079
# Parsing rfc5168
# Parsing rfc5194
# Parsing rfc5245
# Parsing rfc5263
# Parsing rfc5264
# Parsing rfc5359
# Parsing rfc5363
# Parsing rfc5365
# Parsing rfc5367
# Parsing rfc5368
# Parsing rfc5369
# Parsing rfc5370
# Parsing rfc5373
# Parsing rfc5456
# Parsing rfc5589
# Parsing rfc5627
# Parsing rfc5629
# Parsing rfc5631
# Parsing rfc5806
# Parsing rfc5853
# Parsing rfc5898
# Parsing rfc5923
# Parsing rfc6035
# Parsing rfc6072
# Parsing rfc6080
# Parsing rfc6157
# Parsing rfc6314
# Parsing rfc6337
# Parsing rfc6446
# Parsing rfc6787
# Parsing rfc6795
# Parsing rfc7247
# Parsing rfc7315
# Parsing rfc7701
# Parsing rfc7702
# Parsing rfc8079
# Parsing rfc3264
# Parsing rfc3320
# Parsing rfc3485
# Parsing rfc3489
# Parsing rfc3520
# Parsing rfc3524
# Parsing rfc3550
# Parsing rfc3605
# Parsing rfc3631
# Parsing rfc3830
# Parsing rfc3862
# Parsing rfc3864
# Parsing rfc3890
# Parsing rfc3924
# Parsing rfc3926
# Parsing rfc3953
# Parsing rfc3989
# Parsing rfc4046
# Parsing rfc4077

# %%
from multiprocessing.dummy import Pool as ThreadPool

# %%
pool = ThreadPool(20)
results = pool.map(parse_one, to_parse)

pool.close()
pool.join()
# Out:
# Parsing rfc4081
# Parsing rfc5025Parsing rfc6314
# Parsing rfc6881
# Parsing rfc7647
# Parsing rfc5263
# Parsing rfc5359Parsing rfc7748
# Parsing rfc3043
#
#
# Parsing rfc5362
# Parsing rfc5802
# Parsing rfc2955
# Parsing bcp9
# Parsing rfc6055
# Parsing draft-ietf-httpbis-rfc6265bis
# Parsing rfc3464
# Parsing rfc2964
# Parsing rfc1898
# Parsing rfc1320
# Parsing rfc2653
# Parsing draft-ietf-acme-email-smime
# Parsing rfc8710
# Parsing rfc4356
# Parsing rfc3603
# Parsing rfc3605
# Parsing rfc3611
# Parsing draft-ietf-lisp-ecdsa-auth
# Parsing rfc3044
# Parsing draft-ietf-extra-imap4rev2
# Parsing rfc2993
# Parsing rfc1421
# Parsing rfc1983
# Parsing rfc5367
# Parsing rfc5369
# Parsing rfc5552
# Parsing rfc8048
# Parsing rfc2821
# Parsing rfc4119
# Parsing rfc2045
# Parsing rfc8032
# Parsing rfc2476
# Parsing rfc2959
# Parsing rfc6055
# Parsing rfc6365
# Parsing rfc3613
# Parsing rfc6919
# Parsing rfc3507
# Parsing rfc7255
# Parsing draft-ietf-regext-rfc7482bis
# Parsing draft-ietf-jmap-jscontact
# Parsing rfc3120
# Parsing rfc1422
# Parsing rfc3022
# Parsing draft-ietf-rum-rue
# Parsing rfc8174
# Parsing rfc2150
# Parsing rfc4145
# Parsing rfc7026
# Parsing rfc5627
# Parsing rfc5629
# Parsing rfc5638
# Parsing rfc2616
# Parsing status
# Parsing rfc3550
# Parsing rfc3794
# Parsing rfc2981
# Parsing rfc7350
# Parsing rfc1766
# Parsing rfc2910
# Parsing rfc3625Parsing rfc6365
#
# Parsing rfc6505
# Parsing draft-ietf-tsvwg-rfc4960-bis
# Parsing draft-ietf-lamps-header-protection
# Parsing rfc2975
# Parsing rfc3187
# Parsing draft-kinamdar-dispatch-sip-auto-peer
# Parsing rfc7069
# Parsing rfc5727
# Parsing rfc1423
# Parsing rfc2604
# Parsing rfc4190
# Parsing draft-ryzokuken-datetime-extended
# Parsing rfc3632
# Parsing draft-ietf-oauth-access-token-jwt
# Parsing rfc3028
# Parsing rfc7904
# Parsing rfc2048
# Parsing rfc2982
# Parsing rfc1958
# Parsing rfc6505
# Parsing rfc6943
# Parsing rfc6914
# Parsing rfc2912
# Parsing rfc3188
# Parsing rfc3868
# Parsing rfc7146
# Parsing rfc2636
# Parsing rfc3156
# Parsing rfc3550
# Parsing rfc3597
# Parsing draft-koster-rep
# Parsing rfc3641
# Parsing rfc1424
# Parsing rfc5839
# Parsing rfc4313
# Parsing rfc3028
# Parsing rfc3160
# Parsing rfc8464
# Parsing rfc3004
# Parsing rfc3406
# Parsing rfc6943
# Parsing rfc7322
# Parsing rfc7247Parsing rfc2026
#
# Parsing rfc7702
# Parsing rfc8599
# Parsing rfc8224
# Parsing rfc2913
# Parsing rfc2049
# Parsing rfc4414
# Parsing rfc2660
# Parsing draft-pantos-hls-rfc8216bis
# Parsing rfc3335
# Parsing rfc3539
# Parsing rfc7247
# Parsing rfc7333
# Parsing rfc3642
# Parsing rfc5875
# Parsing rfc3659
# Parsing rfc4317
# Parsing rfc3196
# Parsing rfc3014
# Parsing rfc2915
# Parsing bcp14
# Parsing rfc2119
# Parsing rfc7612
# Parsing rfc8465
# Parsing rfc4483
# Parsing rfc6618
# Parsing draft-reddy-add-server-policy-selection
# Parsing rfc8418
# Parsing rfc3656
# Parsing rfc7681Parsing rfc5989
# Parsing rfc4152
#
# Parsing rfc2762
# Parsing rfc4321Parsing rfc2130
#
# Parsing rfc7383
# Parsing rfc3696
# Parsing rfc3697
# Parsing rfc3252
# Parsing rfc3031
# Parsing rfc2919
# Parsing draft-tschofenig-rats-psa-token
# Parsing draft-ietf-rum-rue
# Parsing rfc5245
# Parsing rfc5780
# Parsing rfc7643
# Parsing rfc6787
# Parsing rfc6896
# Parsing rfc8419
# Parsing rfc4179
# Parsing rfc3676
# Parsing rfc3550
# Parsing draft-ietf-avt-profile
# Parsing rfc4336
# Parsing rfc6011
# Parsing rfc2845
# Parsing rfc2119
# Parsing rfc3731
# Parsing rfc7400
# Parsing rfc3775
# Parsing rfc6151
# Parsing rfc2160
# Parsing draft-turner-sodp-profile
# Parsing rfc2926
# Parsing rfc5923
# Parsing rfc5947
# Parsing rfc1127
# Parsing rfc4195
# Parsing draft-peterson-stir-messaging
# Parsing rfc7643
# Parsing rfc7644
# Parsing rfc3687
# Parsing rfc4347
# Parsing rfc2279
# Parsing rfc2447
# Parsing rfc6035
# Parsing rfc6072
# Parsing rfc6076
# Parsing draft-zhang-alto-multipart
# Parsing rfc7486
# Parsing rfc3732
# Parsing rfc1320
# Parsing draft-ietf-httpbis-digest-headersParsing rfc1034
#
# Parsing rfc3032
# Parsing rfc3112
# Parsing rfc2938
# Parsing rfc6140
# Parsing rfc1138
# Parsing bcp14
# Parsing rfc2119
# Parsing rfc4198
# Parsing rfc3691
# Parsing rfc3398
# Parsing rfc3420
# Parsing rfc8077
# Parsing draft-irtf-pearg-numeric-ids-generation
# Parsing rfc3797
# Parsing rfc6080
# Parsing rfc6140
# Parsing rfc4353
# Parsing rfc3188
# Parsing rfc3257
# Parsing rfc3833
# Parsing rfc7495
# Parsing rfc2957
# Parsing rfc6230
# Parsing rfc2822
# Parsing rfc2958
# Parsing rfc5226
# Parsing rfc1143
# Parsing rfc3262
# Parsing rfc3264
# Parsing rfc3311
# Parsing rfc4032
# Parsing rfc5245
# Parsing rfc5741
# Parsing rfc3743
# Parsing draft-kario-gss-qr-kex
# Parsing rfc3821Parsing rfc3034
#
# Parsing rfc3459
# Parsing rfc3462
# Parsing rfc8077
# Parsing rfc8187
# Parsing rfc3447
# Parsing rfc2130
# Parsing rfc2279
# Parsing draft-dnoveck-nfsv4-rfc5661bis-base
# Parsing rfc4367
# Parsing rfc2958
# Parsing rfc6442
# Parsing rfc7573
# Parsing rfc4078
# Parsing rfc2967
# Parsing rfc1148
# Parsing rfc6272
# Parsing draft-mclaggan-wccp-v2rev1
# Parsing rfc3781
# Parsing rfc1305
# Parsing rfc2818
# Parsing draft-dnoveck-nfsv4-rfc5661bis-base
# Parsing draft-foudil-securitytxt
# Parsing rfc3501
# Parsing rfc3107
# Parsing rfc8187
# Parsing rfc8280
# Parsing rfc4435
# Parsing rfc3920
# Parsing rfc2985
# Parsing rfc7596
# Parsing rfc4408
# Parsing rfc1349
# Parsing rfc3050
# Parsing rfc3315
# Parsing rfc6446
# Parsing rfc6447
# Parsing rfc3834
# Parsing rfc3651
# Parsing draft-foudil-securitytxt
# Parsing rfc2518
# Parsing rfc4442
# Parsing rfc3118
# Parsing rfc3018
# Parsing rfc6337
# Parsing rfc7989
# Parsing rfc3795
# Parsing rfc1423
# Parsing rfc1597
# Parsing rfc4519
# Parsing rfc8280
# Parsing rfc2360
# Parsing rfc5234Parsing rfc3957
#
# Parsing rfc1350
# Parsing draft-ietf-sipcore-rfc4028bis
# Parsing rfc3842Parsing rfc6443
#
# Parsing rfc3862
# Parsing rfc3865
# Parsing rfc7602
# Parsing rfc3263
# Parsing rfc4343
# Parsing rfc3676
# Parsing rfc3709
# Parsing rfc1320
# Parsing rfc1334
# Parsing rfc4463
# Parsing rfc2518
# Parsing rfc3470
# Parsing rfc3028
# Parsing rfc3066
# Parsing rfc1627
# Parsing bcp14
# Parsing rfc2119
# Parsing rfc2373
# Parsing rfc3229
# Parsing rfc4122
# Parsing rfc4524
# Parsing rfc3866
# Parsing rfc2484
# Parsing rfc7655
# Parsing rfc3313
# Parsing rfc3455
# Parsing rfc3485
# Parsing rfc3891
# Parsing rfc3911
# Parsing rfc3976
# Parsing rfc4028
# Parsing rfc4083
# Parsing rfc4353
# Parsing rfc4435
# Parsing rfc4453
# Parsing rfc4473
# Parsing rfc3798
# Parsing rfc1352
# Parsing rfc1370
# Parsing rfc4366
# Parsing rfc4473
# Parsing rfc3520
# Parsing rfc3576
# Parsing rfc6751
# Parsing rfc822
# Parsing rfc3530
# Parsing rfc3080
# Parsing rfc3885
# Parsing rfc3230
# Parsing rfc4728
# Parsing rfc1425
# Parsing rfc4825
# Parsing rfc4826
# Parsing rfc5039
# Parsing rfc2640
# Parsing rfc7668
# Parsing rfc4475
# Parsing rfc4568
# Parsing rfc1423
# Parsing rfc1446
# Parsing rfc3801
# Parsing rfc3986
# Parsing rfc5246
# Parsing rfc3579
# Parsing rfc6809
# Parsing rfc4474
# Parsing rfc5246
# Parsing rfc1849
# Parsing rfc3648
# Parsing rfc4931
# Parsing rfc3081
# Parsing rfc3273
# Parsing rfc3886
# Parsing rfc1460
# Parsing rfc4479
# Parsing rfc5057
# Parsing rfc3010
# Parsing rfc1433
# Parsing rfc7696
# Parsing rfc7118
# Parsing rfc3537
# Parsing rfc2047
# Parsing rfc3851
# Parsing rfc3580
# Parsing rfc3648
# Parsing rfc3707
# Parsing rfc4932
# Parsing rfc3082
# Parsing rfc1479
# Parsing rfc3887
# Parsing rfc5112
# Parsing rfc1455
# Parsing rfc3335
# Parsing rfc3550
# Parsing rfc3551
# Parsing rfc4495
# Parsing std1
# Parsing std11
# Parsing std13
# Parsing rfc3010
# Parsing rfc3216
# Parsing rfc3550
# Parsing rfc3560
# Parsing rfc7702
# Parsing rfc7724
# Parsing rfc7247
# Parsing rfc7254
# Parsing rfc3797
# Parsing rfc3871
# Parsing rfc3730
# Parsing rfc4291
# Parsing rfc5280
# Parsing rfc4960
# Parsing rfc5589
# Parsing rfc5741
# Parsing rfc5890
# Parsing rfc3084
# Parsing rfc2060
# Parsing rfc1510
# Parsing rfc5239
# Parsing rfc3890
# Parsing rfc3891
# Parsing rfc3903
# Parsing rfc3911
# Parsing rfc3920
# Parsing rfc3939
# Parsing rfc1506
# Parsing rfc4504
# Parsing rfc3862Parsing rfc3426
# Parsing rfc3863
#
# Parsing rfc7739
# Parsing rfc8489
# Parsing rfc3565
# Parsing rfc3730
# Parsing rfc3735
# Parsing rfc3961
# Parsing rfc3085
# Parsing rfc3958
# Parsing rfc5261
# Parsing rfc1517
# Parsing rfc1544
# Parsing rfc3470
# Parsing rfc3707
# Parsing rfc3735
# Parsing rfc2110
# Parsing rfc4535
# Parsing rfc7798
# Parsing rfc3631
# Parsing rfc3711
# Parsing rfc3659
# Parsing rfc4130
# Parsing rfc3875
# Parsing rfc6365
# Parsing rfc6910
# Parsing rfc3805
# Parsing rfc5031
# Parsing rfc5280
# Parsing rfc8599
# Parsing rfc8839
# Parsing rfc4051
# Parsing rfc3091
# Parsing rfc5234
# Parsing rfc5741
# Parsing rfc5952
# Parsing rfc1531
# Parsing std5
# Parsing rfc1704
# Parsing rfc5262
# Parsing rfc3966
# Parsing rfc3981
# Parsing rfc3920
# Parsing rfc3981
# Parsing rfc5741
# Parsing rfc5923
# Parsing rfc5924
# Parsing rfc2157
# Parsing rfc3965
# Parsing rfc4303
# Parsing std68
# Parsing rfc8433
# Parsing rfc4542
# Parsing rfc7804
# Parsing rfc3805
# Parsing rfc3808
# Parsing rfc3108
# Parsing rfc4122
# Parsing rfc4230
# Parsing rfc1533
# Parsing bcp14
# Parsing rfc2119
# Parsing rfc2617
# Parsing rfc5234
# Parsing rfc6151
# Parsing rfc7234
# Parsing rfc5411
# Parsing rfc1725
# Parsing std66
# Parsing std68
# Parsing rfc7849
# Parsing rfc3983
# Parsing rfc8141
# Parsing rfc5923
# Parsing rfc5924
# Parsing rfc6216
# Parsing rfc3983
# Parsing rfc2183
# Parsing rfc2184
# Parsing rfc4566
# Parsing rfc4047
# Parsing rfc3748
# Parsing rfc3862
# Parsing rfc3863
# Parsing rfc3863
# Parsing rfc3920
# Parsing rfc3931
# Parsing rfc7810
# Parsing rfc4253
# Parsing rfc3164
# Parsing rfc1750
# Parsing rfc1751
# Parsing rfc1545
# Parsing rfc3987
# Parsing draft-ietf-rum-rue
# Parsing rfc3608
# Parsing bcp14
# Parsing bcp85
# Parsing rfc2119
# Parsing rfc2327
# Parsing rfc2543
# Parsing rfc3327Parsing rfc7616
#
# Parsing rfc3515
# Parsing rfc3608Parsing rfc5661
# Parsing rfc6230
# Parsing rfc3725
# Parsing rfc3891
# Parsing rfc3893
# Parsing rfc3911
#
# Parsing rfc6406
# Parsing rfc4168
# Parsing rfc4244
# Parsing rfc4474
# Parsing rfc5246
# Parsing rfc5627
# Parsing std1
# Parsing draft-ietf-avtcore-multi-party-rtt-mix
# Parsing rfc4130
# Parsing rfc4155
# Parsing rfc7076
# Parsing rfc5322Parsing draft-bichot-msync
#
# Parsing rfc2231
# Parsing rfc5688
# Parsing rfc3264
# Parsing rfc3262
# Parsing rfc3263
# Parsing bcp14
# Parsing rfc1035
# Parsing rfc7906
# Parsing rfc3179
# Parsing rfc1810
# Parsing rfc3931
# Parsing rfc3981
# Parsing rfc3983
# Parsing rfc4181
# Parsing rfc4346
# Parsing rfc5658
# Parsing rfc1561
# Parsing rfc4180
# Parsing rfc3766
# Parsing rfc3095
# Parsing rfc6787
# Parsing rfc8224
# Parsing rfc6125
# Parsing rfc2148
# Parsing rfc5850
# Parsing rfc4004
# Parsing rfc8174
# Parsing std68
# Parsing bcp14
# Parsing rfc2119
# Parsing rfc2543
# Parsing rfc5741
# Parsing rfc7501
# Parsing rfc2237
# Parsing rfc2291
# Parsing rfc3191
# Parsing rfc1826
# Parsing rfc7970
# Parsing rfc4568
# Parsing rfc4572
# Parsing rfc4181
# Parsing rfc4249
# Parsing rfc7247
# Parsing rfc7462
# Parsing rfc5989
# Parsing rfc6125
# Parsing rfc4239Parsing rfc1577
#
# Parsing rfc5461
# Parsing rfc2157
# Parsing rfc2180
# Parsing rfc3819
# Parsing rfc3264
# Parsing rfc3304
# Parsing rfc5874
# Parsing rfc2278
# Parsing rfc2360
# Parsing rfc2396
# Parsing rfc2396
# Parsing rfc4037Parsing rfc2459
#
# Parsing rfc3192
# Parsing rfc4462
# Parsing bcp14
# Parsing rfc1321
# Parsing rfc2119
# Parsing rfc2543
# Parsing rfc4960
# Parsing rfc5234
# Parsing std1
# Parsing std68
# Parsing rfc7247
# Parsing rfc7332
# Parsing rfc1828
# Parsing rfc8002
# Parsing rfc6357
# Parsing rfc1611
# Parsing rfc4574
# Parsing rfc4446
# Parsing rfc2183
# Parsing rfc2184
# Parsing rfc2192
# Parsing rfc5625
# Parsing rfc4240
# Parsing rfc4249
# Parsing rfc4263
# Parsing rfc1123
# Parsing rfc1191
# Parsing rfc3497
# Parsing rfc4088
# Parsing rfc6050
# Parsing rfc2298
# Parsing rfc7501
# Parsing draft-ietf-rum-rue
# Parsing rfc6272
# Parsing rfc8224
# Parsing bcp14
# Parsing bcp78
# Parsing rfc6271
# Parsing rfc3259Parsing rfc4572
# Parsing rfc4595
#
# Parsing rfc1864
# Parsing rfc3830
# Parsing rfc3851
# Parsing rfc3852
# Parsing rfc6950
# Parsing rfc2484
# Parsing rfc2566
# Parsing rfc8007
# Parsing rfc1612
# Parsing rfc2193
# Parsing rfc4579
# Parsing rfc4289
# Parsing rfc5731
# Parsing rfc3568
# Parsing rfc4446
# Parsing rfc4479
# Parsing rfc4480
# Parsing rfc4122
# Parsing rfc4130
# Parsing rfc4151
# Parsing rfc2305
# Parsing rfc4620
# Parsing rfc1910
# Parsing rfc3266
# Parsing rfc6086
# Parsing rfc6443
# Parsing rfc6679
# Parsing rfc1620
# Parsing rfc2197
# Parsing rfc7118
# Parsing rfc8489
# Parsing bcp14
# Parsing bcp212
# Parsing rfc2616
# Parsing rfc2661
# Parsing rfc8052
# Parsing rfc4596
# Parsing rfc3605
# Parsing rfc2885
# Parsing rfc3885
# Parsing rfc3931
# Parsing rfc3972
# Parsing rfc1288
# Parsing rfc5732
# Parsing rfc4168
# Parsing rfc4179
# Parsing rfc4180
# Parsing rfc7315
# Parsing draft-ryzokuken-datetime-extended
# Parsing rfc2885
# Parsing rfc4482
# Parsing rfc4635
# Parsing rfc1938
# Parsing rfc3282
# Parsing rfc2311
# Parsing rfc1626
# Parsing rfc2198
# Parsing rfc2119
# Parsing rfc2543
# Parsing rfc3262
# Parsing rfc3311
# Parsing rfc3725
# Parsing rfc4244
# Parsing rfc4474
# Parsing rfc6881
# Parsing rfc7433
# Parsing rfc2119
# Parsing rfc5234
# Parsing rfc6749
# Parsing rfc6272
# Parsing rfc6665
# Parsing rfc6914
# Parsing rfc7315
# Parsing rfc3428
# Parsing rfc4612Parsing rfc8053
#
# Parsing rfc6795
# Parsing rfc7044
# Parsing rfc1738
# Parsing rfc3015
# Parsing rfc3241
# Parsing rfc4483
# Parsing rfc4823
# Parsing rfc5890
# Parsing rfc5936
# Parsing rfc3015
# Parsing rfc3421
# Parsing rfc2661Parsing rfc1939
#
# Parsing rfc2707
# Parsing rfc4485
# Parsing rfc4647
# Parsing rfc4716
# Parsing rfc4055
# Parsing rfc2346
# Parsing rfc1648
# Parsing rfc3297
# Parsing rfc8075
# Parsing rfc4650
# Parsing rfc2221
# Parsing rfc7866
# Parsing rfc8862
# Parsing rfc3323
# Parsing rfc3388
# Parsing rfc3393
# Parsing rfc3794
# Parsing rfc3968
# Parsing rfc3298
# Parsing rfc3470
# Parsing rfc3525
# Parsing rfc4855
# Parsing rfc4721
# Parsing rfc2707
# Parsing rfc2781
# Parsing rfc5966
# Parsing rfc2376
# Parsing rfc6750
# Parsing rfc4647
# Parsing rfc4676
# Parsing rfc4056
# Parsing rfc1649
# Parsing rfc1750
# Parsing rfc1777
# Parsing rfc1948
# Parsing rfc2222
# Parsing rfc3339
# Parsing bcp26
# Parsing rfc4412
# Parsing rfc5226
# Parsing rfc5741
# Parsing rfc7090
# Parsing rfc4661
# Parsing rfc8079
# Parsing rfc8108
# Parsing rfc3622
# Parsing rfc3448
# Parsing draft-ietf-stir-servprovider-oob
# Parsing rfc8848
# Parsing rfc2906
# Parsing rfc4757Parsing rfc4975
#
# Parsing rfc5147
# Parsing rfc6050
# Parsing rfc6265
# Parsing rfc4707
# Parsing rfc1716
# Parsing rfc4086
# Parsing rfc7230
# Parsing rfc2388
# Parsing rfc1949
# Parsing rfc1889
# Parsing rfc1890
# Parsing rfc3629
# Parsing bcp78
# Parsing rfc3263
# Parsing rfc4321
# Parsing rfc5552
# Parsing rfc7501
# Parsing rfc4321
# Parsing rfc5411
# Parsing rfc5638
# Parsing rfc6141
# Parsing rfc6272
# Parsing rfc8599
# Parsing rfc3327
# Parsing bcp14
# Parsing bcp31
# Parsing rfc2231
# Parsing rfc2233
# Parsing draft-peterson-stir-messaging
# Parsing draft-peterson-stir-rfc4916-update
# Parsing rfc3489
# Parsing rfc3525
# Parsing rfc5888
# Parsing rfc8120
# Parsing rfc4694
# Parsing rfc3892
# Parsing rfc5002
# Parsing rfc2911
# Parsing rfc4895
# Parsing rfc5536
# Parsing rfc3340
# Parsing rfc1738Parsing rfc4707
# Parsing rfc4776
#
# Parsing rfc1738
# Parsing rfc1755
# Parsing rfc1964
# Parsing rfc2396
# Parsing rfc2421
# Parsing rfc6272
# Parsing rfc6353
# Parsing rfc5411
# Parsing rfc5479
# Parsing rfc1991
# Parsing rfc4695
# Parsing rfc8233
# Parsing rfc5360
# Parsing bcp98
# Parsing bcp99
# Parsing rfc1035
# Parsing rfc2104
# Parsing rfc2236
# Parsing rfc1890
# Parsing rfc2626
# Parsing rfc3348
# Parsing rfc4941
# Parsing rfc5537
# Parsing rfc1767
# Parsing rfc4918
# Parsing rfc1994
# Parsing rfc2911
# Parsing rfc3157
# Parsing rfc7519
# Parsing rfc4650
# Parsing rfc1889
# Parsing rfc2412
# Parsing rfc5763
# Parsing rfc2423
# Parsing rfc2015
# Parsing rfc6384
# Parsing rfc4696
# Parsing rfc3368
# Parsing rfc8235
# Parsing rfc3325
# Parsing rfc4508
# Parsing rfc3515
# Parsing rfc5502
# Parsing rfc2237
# Parsing rfc2241
# Parsing rfc5545
# Parsing rfc1812
# Parsing rfc3157
# Parsing rfc3169
# Parsing rfc3672
# Parsing rfc4918
# Parsing rfc4930
# Parsing rfc2424
# Parsing rfc2002
# Parsing rfc5036
# Parsing rfc2522
# Parsing rfc2052
# Parsing rfc5318
# Parsing rfc4732Parsing rfc3391
#
# Parsing rfc8252
# Parsing rfc5876
# Parsing rfc7151
# Parsing rfc7662
# Parsing rfc2119
# Parsing rfc2131
# Parsing rfc2242
# Parsing rfc3169
# Parsing rfc3253
# Parsing rfc3780
# Parsing rfc5598
# Parsing rfc2425
# Parsing rfc4930
# Parsing rfc5196
# Parsing rfc2845
# Parsing rfc3257
# Parsing rfc4271
# Parsing rfc3403
# Parsing bcp14
# Parsing rfc2119
# Parsing rfc3325
# Parsing rfc3515
# Parsing rfc3892
# Parsing rfc4508
# Parsing rfc5002
# Parsing rfc5234
# Parsing rfc5318
# Parsing rfc5360
# Parsing rfc5502
# Parsing rfc8174
# Parsing std68
# Parsing rfc8496
# Parsing rfc2068
# Parsing rfc2243
# Parsing rfc6193
# Parsing rfc8295
# Parsing rfc2025
# Parsing rfc8174
# Parsing rfc8252
# Parsing rfc4770
# Parsing rfc7208Parsing rfc8414
#
# Parsing rfc5147
# Parsing rfc5176
# Parsing rfc3876
# Parsing rfc1812
# Parsing rfc1819
# Parsing rfc3253
# Parsing rfc3280
# Parsing rfc2426
# Parsing rfc2442
# Parsing rfc5196
# Parsing rfc5255
# Parsing rfc8498
# Parsing rfc2733
# Parsing rfc5616
# Parsing rfc2244
# Parsing rfc6271
# Parsing rfc6272
# Parsing rfc7340
# Parsing rfc3435
# Parsing rfc4787
# Parsing rfc2040
# Parsing rfc2141
# Parsing std68
# Parsing rfc3204
# Parsing rfc3459
# Parsing rfc8262
# Parsing rfc7482
# Parsing rfc5246
# Parsing rfc5389
# Parsing rfc8389
# Parsing rfc2076Parsing rfc2445
#
# Parsing rfc2119
# Parsing rfc2167
# Parsing rfc3986
# Parsing rfc4183
# Parsing rfc1845
# Parsing rfc3428
# Parsing rfc4975
# Parsing bcp14
# Parsing draft-ietf-lamps-rfc5750-bis
# Parsing rfc5255
# Parsing rfc5337
# Parsing rfc2762
# Parsing rfc2833
# Parsing rfc5751
# Parsing rfc4460
# Parsing rfc7866
# Parsing rfc8224
# Parsing rfc8396
# Parsing rfc3508
# Parsing rfc2245
# Parsing rfc2058Parsing rfc3280
#
# Parsing rfc952
# Parsing bcp13Parsing rfc4234
# Parsing bcp14
# Parsing rfc2045
#
# Parsing rfc2046
# Parsing rfc2119
# Parsing rfc2183
# Parsing rfc2387
# Parsing rfc2205
# Parsing rfc1846
# Parsing rfc8435
# Parsing rfc2480
# Parsing rfc7678
# Parsing rfc2506
# Parsing rfc5415
# Parsing rfc3002
# Parsing rfc4796
# Parsing rfc5466
# Parsing rfc3617
# Parsing rfc5412
# Parsing rfc4660
# Parsing rfc7621
# Parsing rfc2253
# Parsing draft-ietf-lamps-rfc5751-bis
# Parsing rfc2059
# Parsing rfc1849
# Parsing rfc1869
# Parsing rfc822
# Parsing rfc7766
# Parsing rfc2392
# Parsing rfc2552
# Parsing rfc8780
# Parsing rfc5965
# Parsing rfc7719
# Parsing rfc4896
# Parsing rfc4882
# Parsing rfc3624
# Parsing bcp13
# Parsing bcp14
# Parsing bcp26Parsing rfc5466
# Parsing bcp67Parsing rfc2782
# Parsing bcp98
# Parsing rfc2119
# Parsing rfc2779
#
# Parsing rfc1948
# Parsing rfc2002
# Parsing rfc2065
# Parsing rfc5610
#
# Parsing rfc2255
# Parsing rfc2065
# Parsing rfc3009
# Parsing rfc5456
# Parsing rfc5655
# Parsing rfc1878
# Parsing rfc2557
# Parsing draft-ietf-sipbrandy-rtpsec
# Parsing rfc2219
# Parsing rfc2616
# Parsing rfc3204
# Parsing rfc3428
# Parsing rfc3459
# Parsing rfc3851
# Parsing rfc3959
# Parsing rfc4289
# Parsing rfc4483
# Parsing rfc4566
# Parsing rfc4662
# Parsing rfc5368
# Parsing rfc5547
# Parsing rfc5321
# Parsing rfc3501
# Parsing rfc2167
# Parsing rfc2212
# Parsing rfc7507
# Parsing rfc4896
# Parsing rfc6047
# Parsing rfc2327
# Parsing rfc2626
# Parsing rfc2640
# Parsing rfc2822
# Parsing rfc2829
# Parsing rfc8006
# Parsing rfc2848
# Parsing rfc5610
# Parsing rfc5646
# Parsing rfc3257
# Parsing rfc3550
# Parsing rfc3599
# Parsing rfc2405
# Parsing rfc2261
# Parsing rfc2069
# Parsing rfc2082
# Parsing rfc1885
# Parsing rfc5843
# Parsing std1
# Parsing rfc6086
# Parsing rfc6216
# Parsing rfc7852
# Parsing rfc2119
# Parsing rfc3264
# Parsing rfc3325
# Parsing rfc3428
# Parsing rfc3565
# Parsing rfc3840
# Parsing rfc3853
# Parsing rfc3860
# Parsing rfc2565
# Parsing rfc2246
# Parsing rfc2277
# Parsing rfc3263
# Parsing rfc3320
# Parsing rfc3327
# Parsing rfc3489
# Parsing rfc3581
# Parsing rfc3629
# Parsing rfc3840
# Parsing rfc3841
# Parsing rfc3968
# Parsing rfc3969
# Parsing rfc3986
# Parsing rfc4122
# Parsing rfc4340
# Parsing rfc4923
# Parsing rfc3546
# Parsing rfc2967
# Parsing rfc3112
# Parsing rfc3441
# Parsing rfc6072
# Parsing rfc6152
# Parsing rfc2225
# Parsing rfc2029
# Parsing rfc3515
# Parsing rfc3840
# Parsing rfc3891
# Parsing rfc3903
# Parsing rfc3911
# Parsing rfc3968
# Parsing rfc4235
# Parsing rfc4288
# Parsing rfc8304
# Parsing rfc2411
# Parsing rfc5880
# Parsing rfc2085
# Parsing rfc1349
# Parsing rfc2181
# Parsing rfc1891
# Parsing rfc2262
# Parsing rfc3862
# Parsing rfc4566
# Parsing rfc4648
# Parsing rfc4961
# Parsing rfc3651
# Parsing rfc3795
# Parsing rfc3804
# Parsing rfc2566
# Parsing rfc2616
# Parsing rfc2633
# Parsing rfc2646
# Parsing rfc7465
# Parsing rfc8262
# Parsing rfc6272
# Parsing bcp14
# Parsing bcp78
# Parsing rfc2246
# Parsing rfc2633
# Parsing rfc3369
# Parsing rfc2032
# Parsing rfc6350
# Parsing rfc8489
# Parsing rfc8499
# Parsing rfc2095
# Parsing rfc4648
# Parsing rfc2227
# Parsing rfc2433
# Parsing rfc5646
# Parsing rfc5661
# Parsing rfc5721
# Parsing rfc1894
# Parsing rfc4483
# Parsing rfc4485
# Parsing rfc4538
# Parsing rfc4660
# Parsing rfc5057
# Parsing rfc5226
# Parsing rfc5234
# Parsing rfc5627
# Parsing rfc5727
# Parsing rfc5741
# Parsing rfc5839
# Parsing std68
# Parsing rfc6794
# Parsing rfc2279Parsing rfc2264
#
# Parsing rfc2326
# Parsing rfc2327
# Parsing rfc2365
# Parsing rfc5944
# Parsing rfc5966
# Parsing rfc1010
# Parsing rfc2652
# Parsing rfc2038
# Parsing rfc4474
# Parsing rfc4688
# Parsing rfc4977
# Parsing rfc7919
# Parsing rfc3394
# Parsing rfc2251
# Parsing rfc2104
# Parsing rfc2107
# Parsing rfc2440
# Parsing rfc6522
# Parsing rfc5721
# Parsing rfc5730
# Parsing rfc1912
# Parsing rfc2265
# Parsing rfc6795
# Parsing rfc6881
# Parsing rfc6910
# Parsing rfc7200
# Parsing rfc2244
# Parsing rfc2245
# Parsing rfc2303
# Parsing rfc5012
# Parsing rfc2190
# Parsing rfc2368
# Parsing rfc2396
# Parsing rfc2401
# Parsing rfc822
# Parsing std1
# Parsing std11
# Parsing std13
# Parsing std3
# Parsing rfc2885
# Parsing rfc3015
# Parsing rfc3262
# Parsing rfc3263
# Parsing rfc3264
# Parsing rfc3407
# Parsing rfc2693
# Parsing rfc5997
# Parsing rfc4975
# Parsing rfc4976
# Parsing rfc5084
# Parsing rfc3565
# Parsing rfc3851
# Parsing rfc4092
# Parsing rfc5898
# Parsing rfc6216
# Parsing rfc5411
# Parsing rfc6072
# Parsing rfc6272
# Parsing rfc4235
# Parsing bcp119
# Parsing bcp14
# Parsing bcp144
# Parsing bcp98
# Parsing rfc2119
# Parsing rfc3515
# Parsing rfc3680
# Parsing rfc3688
# Parsing rfc5746
# Parsing rfc8520
# Parsing rfc4960Parsing rfc2110
# Parsing rfc2138
#
# Parsing rfc5234
# Parsing rfc5246
# Parsing rfc5389
# Parsing rfc5627
# Parsing rfc768
# Parsing rfc793
# Parsing rfc2536
# Parsing rfc6558
# Parsing rfc1011
# Parsing rfc2252
# Parsing rfc1912
# Parsing rfc7248Parsing rfc1933Parsing rfc2277
#
# Parsing rfc2278
# Parsing rfc2284
#
# Parsing rfc3426
# Parsing rfc3525
# Parsing rfc3891
# Parsing rfc3911
# Parsing rfc4168
# Parsing rfc4425
# Parsing rfc2304
# Parsing rfc2198
# Parsing rfc2211
# Parsing rfc5039
# Parsing rfc5057
# Parsing rfc5058
# Parsing rfc5730
# Parsing rfc5804
# Parsing rfc6056
# Parsing rfc2703
# Parsing rfc5280
# Parsing rfc5438
# Parsing rfc6176
# Parsing rfc2139
# Parsing rfc6591
# Parsing rfc2541
# Parsing rfc8738
# Parsing rfc1937
# Parsing rfc2290
# Parsing rfc7463
# Parsing rfc7614
# Parsing rfc2256
# Parsing rfc5104
# Parsing rfc4485
# Parsing rfc5411
# Parsing rfc6157
# Parsing rfc7989
# Parsing rfc8838
# Parsing rfc2774
# Parsing rfc2326
# Parsing rfc2342
# Parsing rfc2250
# Parsing rfc5480
# Parsing rfc5804
# Parsing rfc6073
# Parsing rfc4346
# Parsing rfc1319
# Parsing rfc6210
# Parsing rfc2165
# Parsing rfc2630
# Parsing rfc2633
# Parsing rfc2759
# Parsing rfc6657
# Parsing rfc1032
# Parsing rfc3840
# Parsing rfc3891
# Parsing rfc3903
# Parsing rfc3911
# Parsing rfc3968
# Parsing std1Parsing rfc4235
# Parsing rfc4579
# Parsing rfc5234
# Parsing std13
#
# Parsing rfc5359
# Parsing std63
# Parsing rfc5589
# Parsing rfc5741
# Parsing rfc7088
# Parsing std66
# Parsing std68
# Parsing rfc5627
# Parsing rfc5630
# Parsing rfc6011
# Parsing rfc6080
# Parsing rfc6223
# Parsing rfc1945
# Parsing rfc7621
# Parsing rfc2301
# Parsing rfc8422Parsing rfc8765
#
# Parsing rfc2281
# Parsing rfc2801
# Parsing rfc2824
# Parsing rfc2345
# Parsing rfc6528
# Parsing rfc5115
# Parsing rfc2326
# Parsing rfc2327
# Parsing rfc2343
# Parsing rfc1832
# Parsing rfc5652
# Parsing rfc6073
# Parsing rfc6120
# Parsing rfc2777
# Parsing rfc2178
# Parsing rfc6838
# Parsing rfc1034
# Parsing rfc1035
# Parsing rfc1043
# Parsing std68
# Parsing rfc7462
# Parsing bcp14
# Parsing bcp149
# Parsing bcp166
# Parsing bcp26
# Parsing bcp66Parsing rfc2044
#
# Parsing rfc2119
# Parsing rfc2141
# Parsing rfc768
# Parsing rfc793
# Parsing std1
# Parsing std6
# Parsing std7
# Parsing rfc3466
# Parsing rfc2285
# Parsing rfc2303
# Parsing rfc2304
# Parsing rfc2305
# Parsing rfc2306
# Parsing rfc2373
# Parsing rfc2384
# Parsing rfc2871
# Parsing rfc5124
# Parsing draft-hoehlhubmer-https-addon
# Parsing rfc2802
# Parsing rfc2354
# Parsing rfc6931
# Parsing rfc1970
# Parsing rfc1945
# Parsing rfc2026
# Parsing rfc2104
# Parsing rfc2268
# Parsing rfc3986
# Parsing rfc4185
# Parsing rfc2786
# Parsing rfc2195
# Parsing rfc1047
# Parsing rfc3568
# Parsing rfc3660
# Parsing rfc3629
# Parsing bcp19
# Parsing rfc2295
# Parsing draft-ietf-emu-eap-tls13
# Parsing rfc2389Parsing rfc2307
#
# Parsing rfc3002
# Parsing rfc3050
# Parsing rfc3099
# Parsing rfc2848
# Parsing rfc2854
# Parsing rfc2361
# Parsing rfc6231
# Parsing rfc5750
# Parsing rfc2459
# Parsing rfc959
# Parsing rfc6917
# Parsing rfc7317
# Parsing rfc2828
# Parsing rfc5128
# Parsing rfc4710Parsing rfc2022
#
# Parsing rfc1048
# Parsing rfc4567
# Parsing rfc4588
# Parsing rfc2202
# Parsing draft-ietf-netconf-tls-client-server
# Parsing rfc2298
# Parsing rfc2310
# Parsing rfc2425
# Parsing rfc2426
# Parsing rfc2445
# Parsing rfc2449
# Parsing rfc2429
# Parsing rfc2308
# Parsing rfc3550
# Parsing rfc3944
# Parsing rfc4463
# Parsing rfc4475
# Parsing rfc5589
# Parsing rfc2705
# Parsing rfc2910
# Parsing rfc2911
# Parsing rfc2913
# Parsing rfc2936
# Parsing rfc5140
# Parsing rfc7035
# Parsing rfc1642
# Parsing rfc5751
# Parsing rfc5753
# Parsing rfc2033
# Parsing rfc7492
# Parsing rfc6231
# Parsing rfc6533
# Parsing rfc2246
# Parsing rfc2264
# Parsing rfc2274
# Parsing rfc1049
# Parsing rfc4918
# Parsing rfc4948
# Parsing draft-ietf-uta-rfc7525bis
# Parsing rfc2316
# Parsing rfc5124
# Parsing rfc5968
# Parsing rfc2848
# Parsing rfc2857
# Parsing rfc2431Parsing rfc2806
# Parsing rfc2848
# Parsing rfc2916
#
# Parsing rfc2957
# Parsing rfc2978
# Parsing rfc2476
# Parsing rfc2486
# Parsing rfc2312
# Parsing rfc5239
# Parsing rfc5341
# Parsing rfc2044
# Parsing rfc2045
# Parsing rfc2047
# Parsing rfc2048
# Parsing rfc2049
# Parsing rfc2152
# Parsing rfc2068Parsing rfc3481
#
# Parsing rfc2076
# Parsing rfc7788
# Parsing rfc2083
# Parsing rfc1052
# Parsing std1
# Parsing std7
# Parsing std8
# Parsing rfc7111Parsing rfc5321
#
# Parsing rfc5452
# Parsing rfc5754
# Parsing rfc2286
# Parsing rfc2320
# Parsing rfc6533
# Parsing rfc7877
# Parsing rfc2919
# Parsing rfc2930
# Parsing rfc6787
# Parsing rfc7051
# Parsing rfc2435
# Parsing rfc2924
# Parsing rfc5347
# Parsing rfc2331
# Parsing rfc2506
# Parsing rfc2530
# Parsing rfc2083
# Parsing rfc2110
# Parsing rfc2131
# Parsing rfc2132
# Parsing rfc2518
# Parsing rfc3318
# Parsing rfc3023
# Parsing rfc7252
# Parsing rfc2289
# Parsing rfc3539
# Parsing rfc3560
# Parsing rfc3631
# Parsing rfc3712
# Parsing rfc1065
# Parsing rfc6121
# Parsing std9
# Parsing draft-ietf-tls-oldversions-deprecate
# Parsing rfc7869Parsing rfc5507
#
# Parsing rfc2326
# Parsing rfc2327
# Parsing rfc2344
# Parsing rfc2448
# Parsing rfc2943
# Parsing rfc7877
# Parsing rfc8881
# Parsing rfc7587
# Parsing rfc5389
# Parsing rfc5438
# Parsing rfc5486
# Parsing rfc2976
# Parsing rfc2995
# Parsing rfc2533
# Parsing rfc2336
# Parsing rfc3331
# Parsing rfc3746
# Parsing rfc2311
# Parsing rfc2313
# Parsing draft-yu-imap-client-id
# Parsing rfc1066
# Parsing rfc2951Parsing rfc2508
#
# Parsing rfc2355
# Parsing rfc8018
# Parsing rfc5797
# Parsing rfc7515
# Parsing rfc5626
# Parsing rfc5628
# Parsing rfc2156
# Parsing rfc3027
# Parsing rfc3264
# Parsing rfc3320
# Parsing rfc3388
# Parsing rfc3550
# Parsing rfc3551
# Parsing rfc3611
# Parsing rfc3640
# Parsing rfc2338
# Parsing rfc3053
# Parsing rfc3332
# Parsing rfc2550
# Parsing rfc8935
# Parsing rfc7285
# Parsing rfc3316
# Parsing rfc2315
# Parsing rfc3748
# Parsing rfc3760
# Parsing rfc2960
# Parsing rfc3012
# Parsing rfc8489
# Parsing rfc8493
# Parsing rfc2369
# Parsing rfc5760
# Parsing rfc5894
# Parsing rfc1073
# Parsing rfc2509
# Parsing rfc3087
# Parsing rfc2554
# Parsing rfc3383
# Parsing rfc2342
# Parsing rfc2360
# Parsing rfc2367
# Parsing rfc3830
# Parsing rfc3890
# Parsing rfc3984
# Parsing rfc2168Parsing rfc3156
# Parsing rfc3195
#
# Parsing rfc8935
# Parsing draft-flanagan-7322bis
# Parsing rfc7516
# Parsing rfc3788
# Parsing rfc3329
# Parsing rfc3436
# Parsing rfc7303
# Parsing rfc2328
# Parsing rfc1079
# Parsing rfc3041
# Parsing rfc8732
# Parsing rfc3108
# Parsing rfc3204
# Parsing rfc3219
# Parsing rfc2379
# Parsing rfc2552
# Parsing rfc2588
# Parsing rfc6021
# Parsing rfc5762
# Parsing draft-irtf-hrpc-association
# Parsing rfc2557
# Parsing rfc2565
# Parsing rfc2373Parsing rfc2569
#
# Parsing rfc2374
# Parsing rfc3204
# Parsing rfc3205
# Parsing rfc3411
# Parsing rfc2181
# Parsing rfc2181
# Parsing rfc2219
# Parsing rfc2219
# Parsing rfc2225
# Parsing rfc2228
# Parsing rfc4046
# Parsing rfc4145
# Parsing rfc4313
# Parsing rfc4336
# Parsing rfc4348
# Parsing rfc7701
# Parsing rfc4040
# Parsing rfc3470
# Parsing rfc3489
# Parsing rfc3501
# Parsing rfc3546
# Parsing rfc3552
# Parsing rfc3805
# Parsing rfc3819
# Parsing rfc3820
# Parsing rfc1084
# Parsing rfc7351
# Parsing rfc2658
# Parsing rfc2380
# Parsing rfc8907
# Parsing draft-irtf-hrpc-association
# Parsing draft-irtf-hrpc-guidelines
# Parsing rfc3075
# Parsing rfc3234
# Parsing rfc5766
# Parsing rfc2228
# Parsing rfc2298Parsing rfc2593
#
# Parsing rfc2303
# Parsing rfc2304
# Parsing rfc2305
# Parsing rfc2309
# Parsing rfc2375
# Parsing rfc4352
# Parsing rfc6055
# Parsing rfc6365
# Parsing rfc6530
# Parsing rfc3236
# Parsing rfc4060
# Parsing rfc3830
# Parsing rfc3867
# Parsing rfc1091
# Parsing draft-irtf-hrpc-guidelines
# Parsing rfc3375
# Parsing rfc2689
# Parsing rfc7515
# Parsing rfc7517
# Parsing draft-eastlake-rfc6931bis-xmlsec-uris
# Parsing rfc2381
# Parsing rfc2385
# Parsing rfc3174
# Parsing rfc2595
# Parsing rfc3470
# Parsing rfc3520
# Parsing rfc3530
# Parsing rfc3546
# Parsing rfc3550
# Parsing rfc3579
# Parsing rfc3588
# Parsing rfc3249
# Parsing rfc3259
# Parsing rfc3298
# Parsing rfc3362
# Parsing rfc4367
# Parsing rfc4396
# Parsing rfc2393Parsing rfc2326
#
# Parsing rfc2331
# Parsing rfc2353
# Parsing rfc3568
# Parsing rfc3588
# Parsing rfc5850
# Parsing rfc5874
# Parsing rfc6442
# Parsing rfc6726
# Parsing rfc3875
# Parsing rfc3955
# Parsing rfc6648
# Parsing rfc4091
# Parsing rfc4092
# Parsing rfc4102
# Parsing rfc1095
# Parsing draft-hoehlhubmer-https-addon
# Parsing draft-ietf-6man-rfc4941bis
# Parsing rfc3375
# Parsing rfc3536
# Parsing rfc2705
# Parsing rfc2730
# Parsing rfc2401
# Parsing rfc2402
# Parsing rfc7519
# Parsing rfc7578
# Parsing rfc8174
# Parsing draft-ietf-roll-efficient-npdao
# Parsing rfc2403
# Parsing rfc2360
# Parsing rfc2360
# Parsing rfc2391
# Parsing rfc3217
# Parsing rfc3282
# Parsing rfc3297
# Parsing rfc3298
# Parsing rfc3335
# Parsing rfc3391
# Parsing rfc2617
# Parsing rfc1864
# Parsing rfc1945
# Parsing rfc2068
# Parsing std1
# Parsing rfc2518
# Parsing rfc4590
# Parsing rfc5090
# Parsing rfc2395
# Parsing rfc3989
# Parsing rfc3998
# Parsing rfc2608
# Parsing rfc4425
# Parsing rfc4435
# Parsing rfc4463
# Parsing rfc4485
# Parsing rfc4566
# Parsing rfc4575
# Parsing rfc4695
# Parsing rfc4749
# Parsing draft-ietf-bfd-optimizing-authentication
# Parsing rfc4103
# Parsing rfc1098
# Parsing rfc7106
# Parsing rfc3536
# Parsing rfc3712
# Parsing rfc3987
# Parsing rfc3987
# Parsing rfc4263
# Parsing rfc4324
# Parsing rfc6912
# Parsing rfc3656
# Parsing rfc3734
# Parsing rfc2736
# Parsing rfc7749
# Parsing rfc3641
# Parsing rfc3642
# Parsing rfc3720
# Parsing draft-sl-rtgwg-far-dcn
# Parsing rfc2396
# Parsing rfc2396
# Parsing rfc2414
# Parsing rfc3220
# Parsing rfc4046
# Parsing rfc4082
# Parsing rfc4867
# Parsing rfc2403
# Parsing rfc7616
# Parsing rfc7877
# Parsing rfc2567
# Parsing rfc2406
# Parsing rfc2409
# Parsing rfc2609
# Parsing rfc3410
# Parsing rfc7825
# Parsing rfc1109
# Parsing rfc4447
# Parsing rfc6943
# Parsing rfc6991
# Parsing rfc4123
# Parsing rfc4145
# Parsing rfc4184
# Parsing rfc3749
# Parsing rfc2775
# Parsing rfc2518
# Parsing rfc3376
# Parsing rfc7808
# Parsing rfc4083
# Parsing rfc4086
# Parsing rfc4107
# Parsing rfc2404
# Parsing rfc5188
# Parsing rfc2421
# Parsing rfc2442
# Parsing rfc2442
# Parsing rfc2461
# Parsing rfc2626
# Parsing rfc3944
# Parsing rfc7826
# Parsing rfc2614
# Parsing rfc3730
# Parsing rfc3733
# Parsing rfc3275
# Parsing rfc7826
# Parsing rfc4298
# Parsing rfc3767
# Parsing rfc1116
# Parsing rfc2407
# Parsing rfc2437Parsing rfc2793
#
# Parsing rfc4447
# Parsing rfc4690
# Parsing rfc3744
# Parsing rfc2645
# Parsing rfc5404
# Parsing rfc8011
# Parsing rfc3748
# Parsing rfc8018
# Parsing rfc3320
# Parsing rfc3485
# Parsing rfc3536
# Parsing rfc3652
# Parsing rfc4112
# Parsing rfc7089
# Parsing rfc2405
# Parsing rfc2408
# Parsing rfc3414
# Parsing rfc4348
# Parsing rfc4351
# Parsing rfc3856
# Parsing rfc3871
# Parsing rfc3887
# Parsing rfc3903
# Parsing rfc3920
# Parsing rfc3943
# Parsing rfc1122
# Parsing rfc3307
# Parsing rfc2068
# Parsing rfc2474
# Parsing rfc2326
# Parsing rfc2565
# Parsing rfc2566
# Parsing rfc2616
# Parsing rfc2617
# Parsing rfc2896
# Parsing rfc2862
# Parsing rfc3361
# Parsing rfc2444
# Parsing rfc4690
# Parsing rfc4766
# Parsing rfc3805
# Parsing rfc3806
# Parsing rfc2646
# Parsing rfc2648
# Parsing rfc3712
# Parsing rfc3735
# Parsing rfc4211
# Parsing rfc2418
# Parsing rfc7622
# Parsing rfc4130
# Parsing rfc4145
# Parsing rfc4153
# Parsing rfc4352
# Parsing rfc4396
# Parsing rfc4425
# Parsing rfc4497
# Parsing rfc4566
# Parsing rfc4569
# Parsing rfc4588
# Parsing rfc4598
# Parsing rfc3983
# Parsing rfc4097
# Parsing rfc5506
# Parsing rfc8040
# Parsing rfc2414
# Parsing rfc2425
# Parsing rfc2426
# Parsing rfc2440
# Parsing rfc2445
# Parsing rfc2450
# Parsing rfc2959
# Parsing rfc3016
# Parsing rfc3344
# Parsing rfc3550
# Parsing rfc3631
# Parsing rfc3652
# Parsing rfc3723
# Parsing rfc3428
# Parsing rfc3794
# Parsing rfc3303
# Parsing rfc2459
# Parsing rfc2522
# Parsing rfc2537
# Parsing rfc5001
# Parsing rfc3977
# Parsing rfc2653
# Parsing rfc2673
# Parsing rfc4683
# Parsing rfc4154
# Parsing rfc7686Parsing rfc2419
#
# Parsing rfc2459
# Parsing rfc2463
# Parsing rfc4612
# Parsing rfc2885
# Parsing rfc3015
# Parsing rfc3313
# Parsing rfc3323
# Parsing rfc3497
# Parsing rfc3525
# Parsing rfc3550
# Parsing rfc3551
# Parsing rfc3764
# Parsing rfc3824
# Parsing rfc3830
# Parsing rfc3924
# Parsing rfc3926
# Parsing rfc3940
# Parsing rfc4111
# Parsing rfc3047
# Parsing rfc1036
# Parsing rfc5584
# Parsing rfc2476
# Parsing rfc2480
# Parsing rfc2480
# Parsing rfc2488
# Parsing rfc2557
# Parsing rfc2570
# Parsing rfc3312
# Parsing rfc5137
# Parsing rfc4217
# Parsing rfc3931
# Parsing rfc3967
# Parsing rfc678
# Parsing rfc3369
# Parsing rfc3370
# Parsing rfc4189
# Parsing rfc4251
# Parsing rfc2705
# Parsing rfc2738
# Parsing rfc4930
# Parsing rfc4933
# Parsing rfc7766
# Parsing rfc7826
# Parsing rfc8324
# Parsing rfc3959
# Parsing rfc4046
# Parsing rfc4101
# Parsing rfc2428Parsing rfc3108
# Parsing rfc3158
#
# Parsing rfc8098
# Parsing rfc4132
# Parsing rfc2464
# Parsing rfc5595
# Parsing rfc1049
# Parsing rfc1154
# Parsing rfc2505
# Parsing rfc5137
# Parsing rfc5198
# Parsing rfc4251
# Parsing rfc3321
# Parsing rfc732
# Parsing rfc4086
# Parsing rfc4278
# Parsing rfc2574
# Parsing rfc2806
# Parsing rfc2808
# Parsing rfc4175
# Parsing rfc5272
# Parsing rfc3170
# Parsing rfc8700
# Parsing rfc3514
# Parsing rfc2431
# Parsing rfc2434
# Parsing rfc4278Parsing rfc4162
#
# Parsing rfc1211
# Parsing rfc8216
# Parsing rfc2521
# Parsing rfc5760
# Parsing rfc5888
# Parsing rfc5945
# Parsing rfc3322
# Parsing rfc2467
# Parsing rfc733
# Parsing rfc5198
# Parsing rfc5280
# Parsing rfc5280
# Parsing rfc5284
# Parsing rfc4306
# Parsing rfc2812
# Parsing rfc4189
# Parsing rfc4215
# Parsing rfc4317
# Parsing rfc4435
# Parsing rfc4442
# Parsing rfc4463
# Parsing rfc4473
# Parsing rfc4542
# Parsing rfc6466
# Parsing rfc4252
# Parsing rfc2573
# Parsing rfc3189
# Parsing rfc1327
# Parsing rfc4168
# Parsing rfc4217
# Parsing rfc4235
# Parsing rfc4244
# Parsing rfc4261
# Parsing rfc1122
# Parsing rfc1175
# Parsing rfc3562
# Parsing rfc4297
# Parsing rfc8225
# Parsing rfc2525
# Parsing rfc2617
# Parsing rfc2630
# Parsing rfc2633
# Parsing rfc2693
# Parsing rfc2716
# Parsing rfc5993
# Parsing rfc3362
# Parsing rfc3435
# Parsing rfc3508
# Parsing rfc3639
# Parsing rfc2471
# Parsing rfc734
# Parsing rfc5284
# Parsing rfc5738
# Parsing rfc2813
# Parsing rfc6498
# Parsing rfc3190
# Parsing rfc4346
# Parsing rfc4347
# Parsing rfc4357
# Parsing rfc4279
# Parsing rfc1521
# Parsing rfc2542
# Parsing rfc4253
# Parsing rfc4254
# Parsing rfc2748
# Parsing rfc5727
# Parsing rfc5367
# Parsing rfc6446
# Parsing rfc2543
# Parsing rfc6665
# Parsing bcp14
# Parsing bcp26
# Parsing rfc2119
# Parsing rfc2616
# Parsing rfc2779
# Parsing rfc2848
# Parsing rfc3311
# Parsing rfc3420
# Parsing rfc3427Parsing rfc1421
# Parsing rfc1496
#
# Parsing rfc3515
# Parsing rfc3680
# Parsing rfc3840
# Parsing rfc3841
# Parsing rfc3842
# Parsing rfc3856
# Parsing rfc3857Parsing rfc8255
# Parsing rfc3858
# Parsing rfc3903
# Parsing rfc3910
# Parsing rfc6015Parsing rfc4235
#
#
# Parsing rfc4354
# Parsing rfc4412
# Parsing rfc4485
# Parsing rfc4488
# Parsing rfc4538
# Parsing rfc4575
# Parsing rfc4579
# Parsing rfc4660
# Parsing rfc4661
# Parsing rfc4662
# Parsing rfc4730
# Parsing rfc1200Parsing rfc4964
# Parsing rfc3986
# Parsing rfc1034
# Parsing rfc2473
# Parsing rfc1630
#
# Parsing rfc736
# Parsing rfc4712
# Parsing rfc2624
# Parsing rfc2821
# Parsing rfc2832
# Parsing rfc8866
# Parsing rfc5738
# Parsing rfc5837
# Parsing rfc2435
# Parsing rfc2446
# Parsing rfc4398
# Parsing rfc3242
# Parsing rfc2542
# Parsing rfc2557
# Parsing rfc2565
# Parsing rfc2565
# Parsing rfc2616
# Parsing rfc2635
# Parsing rfc4366
# Parsing rfc4492
# Parsing rfc4271
# Parsing rfc4556
# Parsing rfc1505
# Parsing rfc765
# Parsing rfc1736
# Parsing rfc2777
# Parsing rfc2792
# Parsing rfc1207
# Parsing rfc2846
# Parsing rfc6064
# Parsing std1
# Parsing std11
# Parsing draft-pep-email
# Parsing rfc8295
# Parsing rfc8551
# Parsing rfc2640
# Parsing rfc2788
# Parsing rfc4782
# Parsing rfc2447
# Parsing rfc2457
# Parsing rfc5837
# Parsing rfc5894
# Parsing rfc5894
# Parsing rfc5987
# Parsing rfc2482
# Parsing rfc2639
# Parsing rfc2733
# Parsing rfc2833
# Parsing rfc3009
# Parsing rfc3016
# Parsing rfc3027
# Parsing rfc3199
# Parsing rfc3259
# Parsing rfc3267
# Parsing rfc4504
# Parsing rfc4568
# Parsing rfc4656
# Parsing rfc3459
# Parsing rfc3851
# Parsing rfc3923
# Parsing rfc2801
# Parsing rfc2802
# Parsing rfc2803
# Parsing rfc1737
# Parsing rfc1521
# Parsing rfc1766
# Parsing rfc1806
# Parsing rfc783
# Parsing rfc6184
# Parsing rfc2848
# Parsing rfc2849
# Parsing rfc2852
# Parsing rfc4497
# Parsing rfc4507
# Parsing rfc1250
# Parsing rfc5230
# Parsing rfc2487
# Parsing rfc2483
# Parsing rfc2967
# Parsing rfc3010
# Parsing rfc3413
# Parsing rfc5987
# Parsing rfc2965
# Parsing rfc4822
# Parsing rfc8580
# Parsing rfc3794
# Parsing rfc4574
# Parsing rfc4867
# Parsing rfc5109
# Parsing rfc2760
# Parsing rfc3303
# Parsing rfc3312
# Parsing rfc3336
# Parsing rfc2828
# Parsing rfc2831
# Parsing rfc1848
# Parsing rfc1738
# Parsing rfc1808
# Parsing rfc821
# Parsing rfc3602
# Parsing rfc4680
# Parsing rfc5114Parsing rfc4130
# Parsing rfc4450
#
# Parsing rfc6185
# Parsing rfc1280
# Parsing rfc2491
# Parsing rfc3057
# Parsing rfc2510
# Parsing rfc3023
# Parsing rfc3075
# Parsing rfc4949Parsing rfc3076
#
# Parsing rfc8970
# Parsing rfc3629
# Parsing rfc3651
# Parsing rfc3660
# Parsing rfc3795
# Parsing rfc4630
# Parsing rfc2821
# Parsing rfc2821
# Parsing rfc2825
# Parsing rfc2361
# Parsing rfc2588
# Parsing rfc2705
# Parsing rfc2771
# Parsing rfc3389
# Parsing rfc2865
# Parsing rfc1864
# Parsing rfc1911
# Parsing rfc4681
# Parsing rfc5246
# Parsing rfc5430
# Parsing rfc6190
# Parsing rfc3631
# Parsing rfc3684
# Parsing rfc1866
# Parsing rfc3080
# Parsing rfc3111
# Parsing rfc3080
# Parsing rfc3104
# Parsing rfc1310
# Parsing rfc2522Parsing rfc2492
#
# Parsing rfc2525
# Parsing rfc2529
# Parsing draft-ietf-emailcore-rfc5322bis
# Parsing rfc2277
# Parsing rfc2326
# Parsing rfc2376
# Parsing rfc2384
# Parsing rfc2396
# Parsing rfc2440
# Parsing rfc2444
# Parsing rfc2445
# Parsing rfc2459
# Parsing rfc2484
# Parsing rfc2516
# Parsing rfc2834
# Parsing rfc2848
# Parsing rfc2974
# Parsing rfc3435
# Parsing rfc3451
# Parsing rfc822
# Parsing rfc854
# Parsing rfc4823
# Parsing rfc5402
# Parsing rfc4791
# Parsing rfc5971
# Parsing rfc3686
# Parsing rfc1945
# Parsing rfc821
# Parsing rfc822
# Parsing rfc976
# Parsing rfc6295
# Parsing rfc2110
# Parsing rfc2141
# Parsing rfc2277
# Parsing rfc822
# Parsing std1
# Parsing std11
# Parsing std13
# Parsing rfc2518
# Parsing rfc3296
# Parsing draft-ietf-httpbis-messaging
# Parsing rfc3111
# Parsing rfc3117
# Parsing rfc1341Parsing rfc2497
#
# Parsing rfc2535
# Parsing rfc2566
# Parsing rfc2571
# Parsing rfc4987
# Parsing rfc2866
# Parsing rfc2846
# Parsing rfc2893
# Parsing rfc4888
# Parsing rfc5751
# Parsing rfc6047
# Parsing rfc6109
# Parsing rfc3047
# Parsing rfc3048
# Parsing rfc855
# Parsing rfc3697
# Parsing rfc3706
# Parsing rfc977
# Parsing draft-ietf-httpbis-semantics
# Parsing rfc3467
# Parsing rfc4823
# Parsing rfc4851
# Parsing rfc6597
# Parsing rfc6347
# Parsing rfc2505
# Parsing rfc2507
# Parsing rfc1360
# Parsing rfc3151
# Parsing rfc3117Parsing rfc5072
# Parsing rfc3122
#
# Parsing rfc3798
# Parsing rfc8098
# Parsing rfc5147
# Parsing rfc2646
# Parsing rfc6657
# Parsing rfc1590
# Parsing rfc3064
# Parsing rfc8551
# Parsing draft-ietf-emailcore-rfc5321bis
# Parsing rfc2898
# Parsing rfc2910
# Parsing rfc2920
# Parsing rfc3746
# Parsing rfc3788
# Parsing rfc3819
# Parsing rfc3890
# Parsing rfc3916
# Parsing rfc2538
# Parsing draft-ietf-oauth-jwsreq
# Parsing std10
# Parsing rfc856
# Parsing rfc2595
# Parsing rfc2608
# Parsing rfc2609
# Parsing rfc2610
# Parsing rfc4934
# Parsing rfc6682
# Parsing rfc3520
# Parsing rfc3546
# Parsing rfc3588
# Parsing rfc3620
# Parsing rfc1403
# Parsing rfc3165
# Parsing rfc3108
# Parsing rfc3119
# Parsing rfc3129
# Parsing rfc3631
# Parsing rfc3862
# Parsing rfc4210
# Parsing rfc1522
# Parsing rfc2508
# Parsing rfc2511
# Parsing rfc5126
# Parsing rfc2924
# Parsing rfc2938
# Parsing rfc2945
# Parsing rfc3931
# Parsing rfc3940
# Parsing rfc3941
# Parsing rfc3842
# Parsing rfc3864
# Parsing rfc3910
# Parsing rfc3922
# Parsing rfc2960
# Parsing rfc3087
# Parsing rfc3108
# Parsing rfc3204
# Parsing rfc3219
# Parsing rfc3234
# Parsing rfc3259
# Parsing rfc3298
# Parsing rfc3362
# Parsing rfc5785
# Parsing rfc2614
# Parsing rfc2616
# Parsing rfc2634
# Parsing rfc2546
# Parsing rfc857
# Parsing rfc5023Parsing rfc6460
#
# Parsing rfc3622
# Parsing rfc3648
# Parsing rfc3653
# Parsing rfc6695
# Parsing rfc1410
# Parsing rfc3170
# Parsing rfc3189
# Parsing rfc3190
# Parsing rfc3259
# Parsing rfc3266
# Parsing rfc3267
# Parsing rfc3298
# Parsing rfc3303
# Parsing rfc3312
# Parsing rfc3322
# Parsing rfc3362
# Parsing rfc3389
# Parsing rfc3435
# Parsing rfc3441
# Parsing rfc3450
# Parsing rfc3196
# Parsing rfc3236
# Parsing rfc3253
# Parsing rfc3275
# Parsing rfc3288
# Parsing rfc3135
# Parsing std11
# Parsing rfc3834
# Parsing rfc3939
# Parsing rfc4021
# Parsing rfc2537
# Parsing rfc2961Parsing rfc2559
#
# Parsing rfc3955
# Parsing rfc3963
# Parsing rfc1521
# Parsing rfc1049
# Parsing rfc1341
# Parsing rfc1421
# Parsing rfc1422
# Parsing rfc1556
# Parsing rfc5172
# Parsing rfc4662
# Parsing rfc4871
# Parsing rfc2560
# Parsing rfc3986
# Parsing rfc4288
# Parsing rfc4416
# Parsing rfc858
# Parsing rfc6266
# Parsing rfc3660
# Parsing rfc3688
# Parsing rfc3696
# Parsing rfc3709
# Parsing rfc3712
# Parsing rfc3720
# Parsing rfc3735
# Parsing rfc3761
# Parsing rfc6709
# Parsing rfc2662
# Parsing rfc6884
# Parsing rfc1500
# Parsing rfc3451
# Parsing rfc1738
# Parsing rfc1808
# Parsing rfc6068
# Parsing rfc5077
# Parsing rfc3305
# Parsing rfc2561
# Parsing rfc1896
# Parsing rfc5440
# Parsing rfc3150
# Parsing rfc5995
# Parsing rfc3012Parsing rfc5321
# Parsing rfc3036
#
# Parsing rfc2099
# Parsing rfc3965
# Parsing rfc4023
# Parsing rfc860
# Parsing rfc4463
# Parsing rfc4622
# Parsing rfc2817
# Parsing rfc2565
# Parsing rfc2566
# Parsing rfc2569
# Parsing rfc2574
# Parsing rfc2590
# Parsing rfc2707
# Parsing rfc2718Parsing rfc3764
# Parsing rfc3778
#
# Parsing rfc1521
# Parsing rfc1540
# Parsing rfc7201
# Parsing rfc3340
# Parsing rfc3349
# Parsing rfc6876
# Parsing rfc1738
# Parsing rfc1808
# Parsing rfc2047
# Parsing rfc822
# Parsing std1
# Parsing std11
# Parsing rfc3696
# Parsing rfc4355
# Parsing rfc5281
# Parsing rfc2045
# Parsing rfc2047
# Parsing rfc2048
# Parsing rfc2049
# Parsing rfc821
# Parsing rfc822
# Parsing rfc934
# Parsing rfc5996
# Parsing rfc2446
# Parsing rfc2447
# Parsing rfc2652
# Parsing rfc2660
# Parsing rfc2798
# Parsing rfc2562
# Parsing rfc3154
# Parsing rfc861
# Parsing rfc4046
# Parsing rfc4067
# Parsing rfc4767
# Parsing rfc6585
# Parsing rfc3041
# Parsing rfc3075
# Parsing rfc3110
# Parsing rfc3824
# Parsing rfc3830
# Parsing rfc3840
# Parsing rfc3862
# Parsing rfc3863
# Parsing rfc3875
# Parsing rfc3881
# Parsing rfc2720
# Parsing rfc2616
# Parsing rfc2652
# Parsing rfc2661
# Parsing rfc2683
# Parsing rfc3367
# Parsing rfc1600
# Parsing rfc5905
# Parsing rfc959
# Parsing std1
# Parsing std11
# Parsing draft-bhutton-json-schema-validation
# Parsing rfc5422
# Parsing rfc5436
# Parsing rfc7525
# Parsing rfc3199
# Parsing rfc3792
# Parsing rfc7273
# Parsing rfc2564
# Parsing rfc3162
# Parsing rfc882
# Parsing rfc4952
# Parsing rfc4083
# Parsing rfc4086
# Parsing rfc4087
# Parsing rfc3887
# Parsing rfc3902
# Parsing rfc2068
# Parsing rfc7230
# Parsing rfc7231
# Parsing rfc2707
# Parsing rfc2711
# Parsing rfc3118
# Parsing rfc3161
# Parsing rfc3368
# Parsing rfc3403
# Parsing rfc3404
# Parsing draft-foudil-securitytxt
# Parsing rfc6709
# Parsing rfc6753
# Parsing rfc2730
# Parsing rfc2776
# Parsing rfc1610
# Parsing rfc5545
# Parsing rfc5546
# Parsing rfc5469
# Parsing rfc6011
# Parsing rfc6042
# Parsing rfc7604
# Parsing rfc2591
# Parsing rfc903
# Parsing rfc3168
# Parsing rfc3981
# Parsing rfc3983
# Parsing rfc4037
# Parsing rfc4051
# Parsing rfc4173
# Parsing rfc5925
# Parsing rfc4093
# Parsing rfc4976
# Parsing rfc5064
# Parsing rfc2734
# Parsing rfc3174
# Parsing rfc6797
# Parsing rfc3208
# Parsing rfc2781
# Parsing rfc2793
# Parsing rfc2808
# Parsing rfc2847
# Parsing rfc3405
# Parsing rfc4021Parsing rfc1720
#
# Parsing rfc1848
# Parsing rfc2015
# Parsing rfc2311Parsing rfc5734
#
# Parsing rfc2316
# Parsing rfc2442
# Parsing rfc2480
# Parsing rfc2510
# Parsing rfc2595
# Parsing rfc2633
# Parsing rfc2649Parsing rfc3859
#
# Parsing rfc6046
# Parsing rfc7728
# Parsing rfc7232
# Parsing rfc4101
# Parsing rfc4110
# Parsing rfc5122
# Parsing rfc2592
# Parsing rfc7919Parsing rfc906
#
# Parsing rfc2806
# Parsing rfc8744Parsing rfc2818
# Parsing rfc2857
#
# Parsing rfc2909
# Parsing rfc3419
# Parsing rfc7236
# Parsing rfc3220
# Parsing rfc3224
# Parsing rfc1745
# Parsing rfc6063
# Parsing rfc2865
# Parsing rfc2866Parsing rfc6837
#
# Parsing rfc2869
# Parsing rfc3507
# Parsing rfc3529
# Parsing rfc3860
# Parsing rfc3966
# Parsing rfc3987
# Parsing rfc4622
# Parsing rfc4952
# Parsing rfc5122
# Parsing rfc5927
# Parsing rfc5878
# Parsing rfc7798
# Parsing rfc7825
# Parsing rfc7826
# Parsing rfc7832
# Parsing rfc7233
# Parsing rfc3193
# Parsing rfc930
# Parsing rfc7566
# Parsing rfc2565
# Parsing rfc2566
# Parsing rfc2567
# Parsing rfc2568
# Parsing rfc4161
# Parsing rfc3470Parsing rfc5322
# Parsing rfc5335
#
# Parsing rfc3510
# Parsing rfc2965Parsing rfc2594
#
# Parsing rfc2971
# Parsing rfc3230
# Parsing rfc3259
# Parsing rfc3275
# Parsing rfc3279
# Parsing rfc1745
# Parsing rfc1780
# Parsing rfc3617
# Parsing rfc3168
# Parsing rfc1825
# Parsing rfc6919
# Parsing rfc6960
# Parsing rfc6066
# Parsing rfc6042
# Parsing rfc6176
# Parsing rfc6367
# Parsing rfc5724
# Parsing rfc2898
# Parsing rfc5929Parsing rfc2911
# Parsing rfc2957
# Parsing rfc2965
# Parsing rfc3023
# Parsing rfc3060
#
# Parsing rfc8088
# Parsing rfc952
# Parsing rfc953
# Parsing rfc3208
# Parsing rfc3348
# Parsing bcp19
# Parsing rfc7826Parsing rfc3819
# Parsing rfc3862
# Parsing rfc3965
# Parsing draft-ietf-httpbis-semantics
#
# Parsing rfc4086
# Parsing rfc5652
# Parsing rfc5750
# Parsing rfc5751
# Parsing rfc5967
# Parsing rfc3485
# Parsing rfc3712
# Parsing rfc3864
# Parsing rfc4189
# Parsing rfc4229
# Parsing rfc3675
# Parsing rfc7234Parsing rfc2569
#
# Parsing rfc2624Parsing rfc7235
#
# Parsing rfc2829
# Parsing rfc3002
# Parsing rfc3257
# Parsing rfc3447
# Parsing rfc3499
# Parsing rfc3219
# Parsing rfc3238Parsing rfc4204
#
# Parsing rfc5337
# Parsing rfc5524
# Parsing rfc2596
# Parsing rfc1878
# Parsing rfc1889
# Parsing rfc1889
# Parsing rfc1891
# Parsing rfc1894
# Parsing rfc1945
# Parsing rfc2046
# Parsing rfc2068
# Parsing rfc2069
# Parsing rfc2075
# Parsing rfc6739
# Parsing rfc6068
# Parsing rfc2626
# Parsing rfc3795
# Parsing rfc2369
# Parsing rfc2788
# Parsing rfc1738
# Parsing rfc1808
# Parsing rfc2732
# Parsing rfc7069
# Parsing rfc7165
# Parsing rfc3072
# Parsing rfc5996
# Parsing rfc6039
# Parsing rfc4301
# Parsing rfc3344
# Parsing rfc3370
# Parsing rfc3451
# Parsing rfc3452
# Parsing rfc6080
# Parsing rfc6108
# Parsing rfc959
# Parsing rfc973
# Parsing rfc6664
# Parsing rfc4412
# Parsing rfc4572
# Parsing rfc4622
# Parsing rfc4918
# Parsing rfc4969
# Parsing rfc3269
# Parsing rfc3722
# Parsing rfc5538
# Parsing rfc8627
# Parsing rfc2608
# Parsing rfc2609
# Parsing rfc2613
# Parsing rfc3651
# Parsing rfc3792
# Parsing rfc2487
# Parsing rfc2595
# Parsing rfc2617
# Parsing rfc2628
# Parsing rfc4213
# Parsing rfc2076
# Parsing rfc2110Parsing rfc3075
# Parsing rfc3076
# Parsing rfc3080
# Parsing rfc3111
# Parsing rfc3145
#
# Parsing rfc2326
# Parsing rfc2500
# Parsing bcp9
# Parsing rfc1036
# Parsing rfc1305
# Parsing rfc1436
# Parsing rfc7230
# Parsing rfc7231
# Parsing rfc7232
# Parsing rfc7233
# Parsing rfc7234
# Parsing rfc7235
# Parsing rfc7252
# Parsing rfc7826
# Parsing rfc8088
# Parsing rfc2660
# Parsing rfc3002
# Parsing rfc3050
# Parsing rfc3795
# Parsing rfc4949
# Parsing rfc2617
# Parsing rfc2639
# Parsing rfc2653
# Parsing rfc2756
# Parsing rfc6749
# Parsing rfc6750
# Parsing rfc7465
# Parsing rfc7507
# Parsing rfc7562
# Parsing rfc5230
# Parsing rfc5231
# Parsing rfc4086
# Parsing rfc1319
# Parsing rfc5033
# Parsing rfc6109
# Parsing rfc6202
# Parsing rfc6094
# Parsing rfc974
# Parsing rfc7107
# Parsing rfc5005
# Parsing rfc3371
# Parsing rfc2649
# Parsing rfc2653
# Parsing rfc2654
# Parsing rfc3252
# Parsing rfc3253
# Parsing rfc3275
# Parsing rfc3280
# Parsing rfc3403
# Parsing rfc3435
# Parsing rfc3508
# Parsing rfc7826
# Parsing rfc1151
# Parsing rfc3741
# Parsing rfc5646
# Parsing rfc5707
# Parsing rfc1590
# Parsing rfc1630
# Parsing rfc1737
# Parsing rfc1738
# Parsing rfc1766
# Parsing rfc1806
# Parsing rfc1808
# Parsing rfc1864
# Parsing rfc1866
# Parsing rfc1867
# Parsing rfc2505
# Parsing rfc2550
# Parsing rfc2616
# Parsing rfc2626
# Parsing rfc2640
# Parsing rfc2640
# Parsing rfc2812
# Parsing rfc2822
# Parsing rfc2993
# Parsing rfc3219
# Parsing rfc3461
# Parsing rfc2781
# Parsing rfc2801
# Parsing rfc2817
# Parsing rfc2818
# Parsing rfc2828
# Parsing rfc2831
# Parsing rfc2854
# Parsing rfc2910
# Parsing rfc2911
# Parsing rfc2914
# Parsing rfc2935
# Parsing rfc8859
# Parsing rfc2614
# Parsing rfc2625
# Parsing rfc7568
# Parsing rfc6208
# Parsing rfc5233
# Parsing rfc4272
# Parsing rfc5086
# Parsing rfc6101
# Parsing rfc980
# Parsing rfc5122
# Parsing rfc5985
# Parsing rfc1644
# Parsing rfc1108
# Parsing rfc2706
# Parsing rfc3374
# Parsing rfc3805
# Parsing rfc3859
# Parsing rfc3860
# Parsing rfc3864
# Parsing rfc3870
# Parsing rfc8152
# Parsing rfc6266
# Parsing rfc6377
# Parsing rfc2650
# Parsing rfc1900Parsing rfc2936
# Parsing rfc2965
# Parsing rfc3023
# Parsing rfc3040
#
# Parsing rfc4066
# Parsing rfc6231
# Parsing rfc6249
# Parsing rfc5256
# Parsing bcp13
# Parsing bcp26
# Parsing rfc2045
# Parsing rfc2048
# Parsing rfc2434
# Parsing std1
# Parsing rfc3372
# Parsing rfc3398
# ...
# Parsing rfc4038
# Parsing rfc8939
# Parsing rfc5406
# Parsing rfc5411
# Parsing rfc5479
# Parsing rfc5576
# Parsing rfc4396
# Parsing rfc4421
# Parsing rfc5740
# Parsing rfc5760
# Parsing rfc5763Parsing rfc7478
# Parsing rfc1206
#
# Parsing rfc5775
# Parsing rfc5939
# Parsing rfc6043
# Parsing rfc6071
# Parsing rfc6507
# Parsing rfc1206
# Parsing rfc3917
# Parsing rfc1906
# Parsing rfc6080
# Parsing rfc6155
# Parsing rfc6280
# Parsing rfc6632
# Parsing rfc6753
# Parsing rfc6772
# Parsing rfc6914
# Parsing rfc7199
# Parsing rfc7200
# Parsing rfc8939
# Parsing rfc7639
# Parsing rfc6597
# Parsing rfc6679
# Parsing rfc6682
# Parsing rfc6683
# Parsing rfc4213
# Parsing rfc4566
# Parsing rfc4943
# Parsing rfc3303
# Parsing rfc3304
# Parsing rfc3424
# Parsing rfc4540
# Parsing rfc4425
# Parsing rfc4553
# Parsing rfc4568
# Parsing rfc4571
# Parsing rfc4573
# Parsing rfc4585
# Parsing rfc4587
# Parsing rfc4588
# Parsing rfc4598
# Parsing rfc4612
# Parsing rfc4629
# Parsing rfc4695
# Parsing rfc4696
# Parsing rfc4710
# Parsing rfc4733
# Parsing rfc4749
# Parsing rfc4842
# Parsing rfc4867
# Parsing rfc5086
# Parsing rfc5087
# Parsing rfc5104
# Parsing rfc5109
# Parsing rfc5117
# Parsing rfc5124
# Parsing rfc5135
# Parsing rfc6726
# Parsing rfc7201
# Parsing rfc7675
# Parsing rfc1234Parsing rfc1234
#
# Parsing rfc7584
# Parsing rfc3955
# Parsing rfc6776
# Parsing rfc8955
# Parsing rfc8955
# Parsing rfc7639
# Parsing rfc7809
# Parsing rfc7066
# Parsing rfc5189
# Parsing rfc5190
# Parsing rfc5118
# Parsing rfc1907
# Parsing rfc1235
# Parsing rfc1235
# Parsing rfc7675
# Parsing rfc5188
# Parsing rfc7826
# Parsing rfc8108
# Parsing rfc8872
# Parsing bcp13
# Parsing bcp47
# Parsing rfc5190
# Parsing bcp73
# Parsing rfc7809
# Parsing rfc8030
# Parsing rfc6798
# Parsing draft-fairhurst-tsvwg-cc
# Parsing draft-ietf-nfsv4-rpcrdma-version-two
# Parsing draft-fairhurst-tsvwg-cc
# Parsing draft-ietf-nfsv4-rpcrdma-version-two
# Parsing rfc5389
# Parsing rfc5741
# Parsing rfc5766
# Parsing rfc6156
# Parsing rfc7092
# Parsing rfc7141
# Parsing rfc7195
# Parsing rfc7201
# Parsing rfc7202
# Parsing bcp78
# Parsing rfc2093
# Parsing rfc1908
# Parsing rfc1240
# Parsing rfc1240
# Parsing rfc5215
# Parsing rfc5225
# Parsing rfc5244
# Parsing rfc7728
# Parsing rfc7825
# Parsing rfc7846
# Parsing draft-ietf-ntp-roughtime
# Parsing draft-ietf-ntp-roughtime
# Parsing rfc2045
# Parsing rfc2048
# Parsing rfc2130
# Parsing rfc6828
# Parsing rfc2141
# Parsing rfc2231
# Parsing rfc2440
# Parsing rfc2779
# Parsing rfc3066
# Parsing rfc3339
# Parsing rfc3553
# Parsing std64
# Parsing rfc7984
# Parsing rfc6314
# Parsing rfc6555
# Parsing rfc8030
# Parsing rfc8288
# Parsing rfc8288
# Parsing rfc8315
# Parsing rfc8315
# Parsing rfc8473
# Parsing rfc2094
# Parsing rfc2367
# Parsing rfc2408
# Parsing rfc2409
# Parsing rfc2412
# Parsing rfc2522
# Parsing rfc2627
# Parsing rfc1244
# Parsing rfc1244
# Parsing rfc7205
# Parsing rfc5285
# Parsing rfc1913
# Parsing draft-ietf-quic-datagram
# Parsing draft-ietf-quic-datagram
# Parsing rfc7850
# Parsing rfc7904
# Parsing rfc7982
# Parsing rfc6843
# Parsing rfc2693
# Parsing rfc3280
# Parsing rfc3450
# Parsing rfc3547
# Parsing rfc3711
# Parsing rfc3740
# Parsing rfc3940
# Parsing draft-ietf-ipsecme-g-ikev2
# Parsing rfc6889
# Parsing rfc6947
# Parsing bcp127
# Parsing bcp131
# Parsing bcp9
# Parsing rfc2026
# Parsing rfc2119
# Parsing rfc3424
# Parsing rfc3550
# Parsing rfc3605
# Parsing rfc4566
# Parsing rfc4787
# Parsing rfc4961
# Parsing rfc5389
# Parsing rfc5741
# Parsing rfc5761
# Parsing rfc5766
# Parsing rfc5780
# Parsing std64
# Parsing rfc2119
# Parsing rfc3312
# Parsing rfc4566
# Parsing rfc8473
# Parsing rfc8594
# Parsing rfc7206
# Parsing rfc7501
# Parsing rfc7604
# Parsing rfc7713
# Parsing rfc7753
# Parsing rfc1270
# Parsing rfc3629
# Parsing rfc3859
# Parsing rfc3860
# Parsing std63
# Parsing rfc3860
# Parsing rfc3922
# Parsing rfc3923Parsing rfc1270
# Parsing rfc3994
# Parsing draft-kunze-coinrg-transport-issues
# Parsing rfc1914
# Parsing draft-kunze-coinrg-transport-issues
# Parsing rfc5371
# Parsing rfc5391
# Parsing rfc5404
# Parsing rfc5450
# Parsing rfc7983
# Parsing rfc4383
# Parsing rfc4563
# Parsing rfc4650
# Parsing rfc4738
# Parsing rfc5374
# Parsing rfc6071
# Parsing rfc6407
# Parsing rfc6849
# Parsing rfc6881
# Parsing rfc6884
# Parsing rfc6904
# Parsing rfc8594
# Parsing rfc8601
# Parsing draft-mcquistin-augmented-udp-example
# Parsing rfc1283
# Parsing rfc5438
# Parsing rfc5547
# Parsing rfc6914
# Parsing rfc7572
# Parsing bcp26
# Parsing bcp78
# Parsing bcp9
# Parsing rfc1036
# Parsing rfc1496
# Parsing rfc1505
# Parsing rfc1737
# Parsing rfc7989
# Parsing rfc8088
# Parsing rfc8404
# Parsing rfc1864
# Parsing rfc1945
# Parsing rfc2026
# Parsing rfc2045
# Parsing rfc2141
# Parsing rfc1283
# Parsing rfc2227
# Parsing rfc2231
# Parsing rfc2369
# Parsing rfc2434
# Parsing rfc2518
# Parsing rfc2557
# Parsing rfc2821
# Parsing rfc2912
# Parsing rfc2919
# Parsing rfc2965
# Parsing rfc3282
# Parsing rfc3798
# Parsing rfc3801
# Parsing rfc822
# Parsing draft-cedik-http-warning
# Parsing draft-mcquistin-augmented-udp-example
# Parsing rfc1928
# Parsing rfc5459
# Parsing rfc8016
# Parsing draft-sharabayko-mops-srt
# Parsing rfc6958
# Parsing rfc1298
# Parsing draft-cedik-http-warning
# Parsing draft-crocker-email-author
# Parsing draft-sharabayko-mops-srt
# Parsing rfc8263Parsing rfc1298
#
# Parsing rfc1970
# Parsing rfc1981
# Parsing rfc1990
# Parsing rfc8601
# Parsing rfc8607
# Parsing rfc8846Parsing rfc5484
#
# Parsing rfc5506
# Parsing rfc5552
# Parsing rfc5574
# Parsing rfc8421
# Parsing rfc3525
# Parsing rfc3819
# Parsing rfc3954
# Parsing rfc4944
# Parsing draft-crocker-email-author
# Parsing draft-crocker-email-deliveredto
# Parsing rfc3525
# Parsing rfc3819
# Parsing rfc3954
# Parsing rfc4944
# Parsing rfc1305
# Parsing rfc1325
# Parsing rfc1305
# Parsing rfc1325
# Parsing rfc6990
# Parsing bcp78
# Parsing rfc3321
# Parsing rfc4465
# Parsing rfc8607
# Parsing draft-ietf-emailcore-rfc5322bis
# Parsing draft-ietf-emailcore-rfc5322bis
# Parsing draft-ietf-httpbis-http2bis
# Parsing rfc5576
# Parsing rfc5577
# Parsing rfc2006
# Parsing rfc5583
# Parsing rfc5584
# Parsing rfc5616
# Parsing rfc5669
# Parsing rfc8849
# Parsing rfc8854
# Parsing rfc8859
# Parsing bcp11
# Parsing rfc2119
# Parsing rfc2766
# Parsing rfc3369
# Parsing rfc3424
# Parsing draft-hurst-quic-rtp-tunnelling
# Parsing rfc8831
# Parsing draft-crocker-email-deliveredto
# Parsing draft-dunglas-vulcain
# Parsing rfc4896
# Parsing rfc1350Parsing rfc1350
# Parsing rfc1361
# Parsing rfc1361
#
# Parsing rfc5097
# Parsing rfc7002
# Parsing draft-ietf-httpbis-http2bis
# Parsing draft-ietf-httpbis-priority
# Parsing rfc5097
# Parsing rfc5686
# Parsing rfc5691
# Parsing rfc4571
# Parsing rfc5760
# Parsing rfc5761
# Parsing rfc5762
# Parsing rfc6056
# Parsing rfc6285
# Parsing rfc6773
# Parsing rfc6947
# Parsing rfc8839
# Parsing rfc8840
# Parsing rfc8843
# Parsing draft-ietf-rtcweb-sdp
# Parsing draft-ietf-rum-rue
# Parsing rfc4566
# Parsing rfc4787
# Parsing rfc5411
# Parsing rfc6128
# Parsing rfc7584
# Parsing rfc8445
# Parsing rfc8829
# Parsing rfc8858
# Parsing rfc8859
# Parsing rfc8866
# Parsing bcp11
# Parsing rfc1510
# Parsing rfc2104
# Parsing rfc2222
# Parsing rfc2289
# Parsing rfc2316
# Parsing rfc2385
# Parsing rfc2402
# Parsing rfc2406
# Parsing rfc2407
# Parsing rfc2411
# Parsing rfc2535
# Parsing rfc2744
# Parsing rfc2017
# Parsing rfc2018
# Parsing draft-dunglas-vulcain
# Parsing draft-gruessing-sdp-http
# Parsing rfc1418Parsing rfc1418
#
# Parsing draft-ietf-httpbis-priority
# Parsing draft-ietf-httpbis-rfc6265bis
# Parsing draft-ietf-httpbis-rfc6265bis
# Parsing draft-ietf-httpbis-semantics
# Parsing draft-ietf-httpbis-semantics
# Parsing draft-ietf-oauth-dpop
# Parsing rfc8858
# Parsing draft-ietf-hip-native-nat-traversal
# Parsing draft-ietf-intarea-gue
# Parsing draft-ietf-rum-rue
# Parsing draft-ietf-taps-interface
# Parsing rfc5761
# Parsing rfc5763
# Parsing rfc5766
# Parsing rfc5780
# Parsing rfc5853
# Parsing rfc6051
# Parsing rfc6062
# Parsing rfc5102
# Parsing rfc5102
# Parsing rfc7003
# Parsing draft-gruessing-sdp-httpParsing rfc5725
#
# Parsing draft-idempotency-header
# Parsing rfc2993
# Parsing rfc3174
# Parsing rfc3445
# Parsing draft-ietf-oauth-dpop
# Parsing draft-thomson-httpbis-http2bis
# Parsing rfc1420
# Parsing rfc1420
# Parsing rfc2024
# Parsing rfc6079
# Parsing draft-idempotency-header
# Parsing draft-ietf-calext-subscription-upgrade
# Parsing rfc7004
# Parsing std61
# Parsing draft-jilongwang-opsawg-cybersmap
# Parsing rfc5760
# Parsing rfc5218
# Parsing rfc5474
# Parsing rfc5505
# Parsing rfc5218
# Parsing rfc5474
# Parsing rfc5505
# Parsing draft-thomson-httpbis-http2bis
# Parsing rfc4229
# Parsing rfc4395
# Parsing rfc4871
# Parsing rfc4871
# Parsing rfc4918
# Parsing rfc4918
# Parsing rfc5322
# Parsing rfc5322
# Parsing rfc5323
# Parsing rfc5323
# Parsing rfc5518
# Parsing rfc1448
# Parsing rfc1448
# Parsing rfc6146
# Parsing rfc2035
# Parsing draft-ietf-emailcore-rfc5321bis
# Parsing draft-ietf-emailcore-rfc5321bis
# Parsing draft-ietf-httpapi-deprecation-header
# Parsing rfc3871
# Parsing rfc3746
# Parsing rfc3862
# Parsing rfc3870
# Parsing rfc4111
# Parsing rfc5920
# Parsing rfc7005
# Parsing rfc7022
# Parsing rfc7058
# Parsing rfc7097
# Parsing rfc2038
# Parsing rfc2045
# Parsing rfc2049
# Parsing rfc2051
# Parsing rfc5518
# Parsing rfc5536
# Parsing rfc5536Parsing rfc5531
#
# Parsing rfc6265
# Parsing rfc6265
# Parsing rfc6266
# Parsing rfc6266
# Parsing rfc6376
# Parsing rfc5531
# Parsing draft-ietf-httpapi-deprecation-header
# Parsing draft-ietf-httpbis-client-hints
# Parsing rfc1449
# Parsing rfc1449
# Parsing rfc7104
# Parsing rfc7160
# Parsing rfc7164
# Parsing rfc7197
# Parsing rfc6189
# Parsing rfc6263
# Parsing rfc6296
# Parsing rfc2052
# Parsing rfc2056
# Parsing draft-ietf-httpbis-client-hints
# Parsing rfc3865
# Parsing rfc3865
# Parsing rfc4021
# Parsing rfc4249
# Parsing rfc4408
# Parsing rfc4408
# Parsing rfc5023
# Parsing rfc5023
# Parsing rfc5064
# Parsing rfc5595
# Parsing rfc5795
# Parsing rfc6021
# Parsing rfc6086
# Parsing rfc6272
# Parsing rfc6285
# Parsing rfc6458
# Parsing rfc5595
# Parsing rfc5795
# Parsing rfc6021
# Parsing rfc6086
# Parsing rfc6272
# Parsing rfc6285
# Parsing rfc6458
# Parsing rfc3628
# Parsing rfc1475
# Parsing rfc1547
# Parsing rfc1475
# Parsing rfc1547
# Parsing rfc6376
# Parsing rfc6648
# Parsing rfc6648
# Parsing rfc7034
# Parsing rfc7198
# Parsing rfc2058
# Parsing rfc2068
# Parsing rfc2070
# Parsing rfc2073
# Parsing rfc6418
# Parsing rfc6309
# Parsing rfc4738
# Parsing bcp26
# Parsing bcp78
# Parsing rfc1305
# Parsing rfc2104
# Parsing rfc2119
# Parsing rfc2409
# Parsing rfc2412
# Parsing rfc2434
# Parsing rfc2486
# Parsing rfc2560
# Parsing rfc3280
# Parsing rfc3394
# Parsing rfc6466
# Parsing rfc6574
# Parsing rfc6466
# Parsing rfc1561Parsing rfc6574
#
# Parsing rfc1594
# Parsing rfc1594
# Parsing rfc1700
# Parsing rfc1716
# Parsing rfc1831
# Parsing rfc1561
# Parsing rfc1594
# Parsing rfc1594
# Parsing rfc1700
# Parsing rfc1716
# Parsing rfc1831
# Parsing rfc7034
# Parsing rfc7230
# Parsing rfc7230
# Parsing rfc7231
# Parsing rfc7232
# Parsing rfc7233
# Parsing rfc7234
# Parsing rfc7235
# Parsing rfc7540
# Parsing rfc7243
# Parsing rfc2077
# Parsing rfc6544
# Parsing rfc6555
# Parsing rfc6751
# Parsing rfc6773
# Parsing rfc6849
# Parsing rfc6877
# Parsing rfc6618Parsing rfc6618
# Parsing rfc6915
#
# Parsing rfc6915
# Parsing rfc1905
# Parsing rfc1906
# Parsing rfc1936
# Parsing rfc1905
# Parsing rfc1906
# Parsing rfc1936
# Parsing rfc2108
# Parsing rfc7244
# Parsing rfc7540
# Parsing rfc7595
# Parsing rfc6889
# Parsing rfc6908
# Parsing rfc2002
# Parsing rfc2058
# Parsing rfc2074
# Parsing rfc2219
# Parsing rfc2353
# Parsing rfc2507
# Parsing rfc2522
# Parsing rfc2896
# Parsing rfc3096
# Parsing rfc6991
# Parsing rfc7202
# Parsing rfc7388
# Parsing rfc6991
# Parsing rfc7202
# Parsing rfc7388
# Parsing rfc2002
# Parsing rfc2058
# Parsing rfc2074
# Parsing rfc2219
# Parsing rfc2353
# Parsing rfc2507
# Parsing rfc2522
# Parsing rfc2896
# Parsing rfc3096
# Parsing rfc2115
# Parsing rfc7294
# Parsing rfc6947
# Parsing rfc7006
# Parsing rfc7022
# Parsing rfc7088
# Parsing rfc7157
# Parsing rfc3252
# Parsing rfc3269
# Parsing rfc773
# Parsing rfc783
# Parsing rfc887
# Parsing rfc906
# Parsing rfc951
# Parsing rfc958
# Parsing rfc2119
# Parsing rfc3311
# Parsing rfc3725
# Parsing rfc3841
# Parsing rfc4412
# Parsing rfc4497Parsing rfc7595
# Parsing rfc7615
# Parsing rfc7615
#
# Parsing rfc4538
# Parsing rfc7694
# Parsing rfc5009
# Parsing rfc5245
# Parsing rfc5479
# Parsing rfc5629
# Parsing rfc6076
# Parsing rfc6228
# Parsing rfc6230
# Parsing rfc6337
# Parsing rfc6794
# Parsing rfc8688
# Parsing rfc8839
# Parsing rfc8840
# Parsing rfc7567
# Parsing rfc7567
# Parsing rfc7600
# Parsing rfc7604
# Parsing rfc7605
# Parsing rfc7720
# Parsing rfc7826
# Parsing rfc7949
# Parsing rfc8045
# Parsing rfc8087
# Parsing rfc8095
# Parsing rfc8166
# Parsing rfc8304
# Parsing rfc8323
# Parsing rfc8376
# Parsing rfc8558
# Parsing rfc8811
# Parsing rfc1010
# Parsing rfc1011
# Parsing rfc1012
# Parsing rfc1024
# Parsing rfc1034
# Parsing rfc1035
# Parsing rfc1060
# Parsing rfc1118
# Parsing rfc1122
# Parsing rfc1175
# Parsing rfc1340
# Parsing rfc3252
# Parsing rfc2122
# Parsing rfc7310
# Parsing rfc7509
# Parsing rfc7838
# Parsing rfc7201
# Parsing rfc7295
# Parsing rfc7362
# Parsing rfc7376
# Parsing rfc2125
# Parsing rfc7604
# Parsing rfc7605
# Parsing rfc7657
# Parsing rfc7826
# Parsing rfc7890
# Parsing rfc8085
# Parsing rfc8261
# Parsing rfc7587
# Parsing rfc7655
# Parsing rfc7657
# Parsing rfc7667
# Parsing rfc7714
# Parsing rfc7728
# Parsing rfc7741
# Parsing rfc7912
# Parsing rfc2132
# Parsing rfc2136
# Parsing rfc7798
# Parsing rfc7826
# Parsing rfc7866
# Parsing rfc8083
# Parsing rfc8269
# Parsing rfc8286
# Parsing rfc8451
# Parsing rfc7912
# Parsing rfc8460
# Parsing rfc8445
# Parsing rfc8825
# Parsing rfc8829
# Parsing rfc8833
# Parsing rfc8834
# Parsing rfc8825
# Parsing rfc8830
# Parsing rfc2138
# Parsing rfc2155
# Parsing rfc8460
# Parsing rfc4021
# Parsing rfc4229
# Parsing rfc7681
# Parsing rfc7681
# Parsing bcp78
# Parsing rfc2156
# Parsing rfc2165
# Parsing rfc2184
# Parsing rfc2198
# Parsing rfc2205
# Parsing rfc2206
# Parsing rfc8836
# Parsing rfc8839
# Parsing rfc8841
# Parsing rfc2207
# Parsing rfc8843
# Parsing rfc8845
# Parsing rfc8853
# Parsing rfc8860
# Parsing rfc8861
# Parsing rfc8867
# Parsing rfc8868
# Parsing rfc2212
# Parsing rfc2213
# Parsing rfc8872
# Parsing rfc3917
# Parsing rfc3940
# Parsing rfc4019
# Parsing rfc2214
# Parsing rfc4046
# Parsing rfc4193
# Parsing rfc2215
# Parsing rfc4340
# Parsing rfc4353
# Parsing rfc4435
# Parsing rfc4445
# Parsing rfc2218
# Parsing rfc4504
# Parsing rfc4566
# Parsing rfc4586
# Parsing rfc2226
# Parsing rfc4628
# Parsing rfc2231
# Parsing rfc4654
# Parsing rfc4689
# Parsing rfc4732
# Parsing rfc4787
# Parsing rfc4815
# Parsing rfc4961
# Parsing rfc4995
# Parsing rfc5101
# Parsing rfc5239
# Parsing rfc5405
# Parsing rfc5411
# Parsing rfc5470
# Parsing rfc5473
# Parsing rfc5479
# Parsing rfc5481
# Parsing rfc5533
# Parsing rfc5567
# Parsing rfc5651
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-54fa44ea1eca> in <module>
#       1 pool = ThreadPool(20)
# ----> 2 results = pool.map(parse_one, to_parse)
#       3
#       4 pool.close()
#       5 pool.join()
#
# /usr/lib/python3.8/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# /usr/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# /usr/lib/python3.8/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# /usr/lib/python3.8/multiprocessing/pool.py in mapstar(args)
#      46
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#      49
#      50 def starmapstar(args):
#
# <ipython-input-151-fb83d393f425> in parse_one(doc)
#       3     if doc in parsed:
#       4         return
# ----> 5     result = get_datatracker_doc_info(doc)
#       6     docs.append(result)
#       7     parsed.append(doc)
#
# <ipython-input-124-99145d7c0fe0> in get_datatracker_doc_info(uri, url)
#       3     r = requests.get(f"https://{url}/doc/{uri}/")
#       4
# ----> 5     main = parse_page(r.content)
#       6
#       7     ref = requests.get(f"https://{url}/doc/{main['label'].lower().replace(' ', '')}/references/")
#
# <ipython-input-122-d59fb830e697> in parse_page(html)
#       1 def parse_page(html):
#       2     soup = BeautifulSoup(html, "html.parser")
# ----> 3     title, rfc_id = list(soup.find("h2").stripped_strings)
#       4     last_updated = soup.find('th', string=re.compile("Last updated")).find_next("td", class_=None).text.strip()
#       5
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
len(docs)
# Out:
# 3194

# %%
len(parsed)
# Out:
# 3360

# %%
len(to_parse)
# Out:
# 81800

# %%
len(set(to_parse))
# Out:
# 10798

# %%
set(parsed).intersection(set(to_parse))
# Out:
# {'bcp14',
#  'bcp76',
#  'bcp85',
#  'bcp98',
#  'bcp99',
#  'rfc1123',
#  'rfc1321',
#  'rfc1750',
#  'rfc1889',
#  'rfc2046',
#  'rfc2069',
#  'rfc2076',
#  'rfc2183',
#  'rfc2246',
#  'rfc2279',
#  'rfc2326',
#  'rfc2327',
#  'rfc2368',
#  'rfc2396',
#  'rfc2401',
#  'rfc2426',
#  'rfc2543',
#  'rfc2616',
#  'rfc2617',
#  'rfc2630',
#  'rfc2633',
#  'rfc2806',
#  'rfc2822',
#  'rfc2849',
#  'rfc2914',
#  'rfc2960',
#  'rfc2976',
#  'rfc3015',
#  'rfc3204',
#  'rfc3262',
#  'rfc3263',
#  'rfc3264',
#  'rfc3268',
#  'rfc3310',
#  'rfc3311',
#  'rfc3313',
#  'rfc3319',
#  'rfc3323',
#  'rfc3325',
#  'rfc3327',
#  'rfc3329',
#  'rfc3372',
#  'rfc3388',
#  'rfc3398',
#  'rfc3427',
#  'rfc3455',
#  'rfc3459',
#  'rfc3487',
#  'rfc3515',
#  'rfc3521',
#  'rfc3578',
#  'rfc3581',
#  'rfc3603',
#  'rfc3608',
#  'rfc3665',
#  'rfc3666',
#  'rfc3680',
#  'rfc3725',
#  'rfc3764',
#  'rfc3824',
#  'rfc3840',
#  'rfc3841',
#  'rfc3842',
#  'rfc3853',
#  'rfc3856',
#  'rfc3857',
#  'rfc3858',
#  'rfc3891',
#  'rfc3892',
#  'rfc3893',
#  'rfc3903',
#  'rfc3910',
#  'rfc3911',
#  'rfc3944',
#  'rfc3959',
#  'rfc3960',
#  'rfc3966',
#  'rfc3968',
#  'rfc3969',
#  'rfc3976',
#  'rfc4006',
#  'rfc4028',
#  'rfc4032',
#  'rfc4083',
#  'rfc4091',
#  'rfc4092',
#  'rfc4117',
#  'rfc4123',
#  'rfc4168',
#  'rfc4169',
#  'rfc4320',
#  'rfc4916',
#  'rfc5626',
#  'rfc5630',
#  'rfc6141',
#  'rfc6665',
#  'rfc7462',
#  'rfc7463',
#  'rfc768',
#  'std1',
#  'std3',
#  'std6'}

# %%
with open("data.json", "w") as f:
    json.dump(docs, f)
with open("parsed.txt", "w") as f:
    f.write("\n".join(parsed))
with open("to_parse.txt", "w") as f:
    f.write("\n".join(to_parse))

# %%
len(set([x["label"] for x in docs]))
# Out:
# 3031

# %%
added = []
removed_duplicates = []
for x in docs:
    if x["label"] not in added:
        added.append(x["label"])
        removed_duplicates.append(x)

# %%
len(removed_duplicates)
# Out:
# 3031

# %%
with open("data.json", "w") as f:
    json.dump(removed_duplicates, f)
with open("parsed.txt", "w") as f:
    f.write("\n".join(parsed))
with open("to_parse.txt", "w") as f:
    f.write("\n".join(to_parse))

# %%
removed_duplicates[3]
# Out:
# {'title': "Actions Addressing Identified Issues with the Session Initiation Protocol's (SIP) Non-INVITE Transaction",
#  'text': 'https://www.rfc-editor.org/rfc/rfc4320.txt',
#  'pdf': 'https://www.rfc-editor.org/rfc/pdfrfc/rfc4320.txt.pdf',
#  'html': 'https://tools.ietf.org/html/rfc4320',
#  'label': 'RFC 4320',
#  'aka': [],
#  'last_updated': '2015-10-14',
#  'updates': [{'uri': '/doc/rfc3261/', 'name': 'RFC 3261'}],
#  'updated_by': [],
#  'obsoletes': [],
#  'obsoleted_by': [],
#  'authors': [{'email': '/person/rjsparks@nostrum.com',
#    'name': 'Robert Sparks'}],
#  'references': [{'name': 'BCP 78',
#    'status': 'Best Current Practice',
#    'type': 'normatively references',
#    'downref': ''},
#   {'name': 'RFC 3261',
#    'status': 'Proposed Standard',
#    'type': 'normatively references',
#    'downref': ''},
#   {'name': 'RFC 3263',
#    'status': 'Proposed Standard',
#    'type': 'normatively references',
#    'downref': ''},
#   {'name': 'RFC 4321',
#    'status': 'Informational',
#    'type': 'normatively references',
#    'downref': 'Downref'}],
#  'referenced_by': [{'name': 'RFC 5552',
#    'status': 'Proposed Standard',
#    'type': 'normatively references',
#    'downref': ''},
#   {'name': 'RFC 7501',
#    'status': 'Informational',
#    'type': 'normatively references',
#    'downref': ''},
#   {'name': 'RFC 4321',
#    'status': 'Informational',
#    'type': 'informatively references',
#    'downref': ''},
#   {'name': 'RFC 5411',
#    'status': 'Informational',
#    'type': 'informatively references',
#    'downref': ''},
#   {'name': 'RFC 5638',
#    'status': 'Informational',
#    'type': 'informatively references',
#    'downref': ''},
#   {'name': 'RFC 6141',
#    'status': 'Proposed Standard',
#    'type': 'informatively references',
#    'downref': ''},
#   {'name': 'RFC 6272',
#    'status': 'Informational',
#    'type': 'informatively references',
#    'downref': ''},
#   {'name': 'RFC 8599',
#    'status': 'Proposed Standard',
#    'type': 'informatively references',
#    'downref': ''}]}
