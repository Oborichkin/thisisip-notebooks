# %%
import re
import json

import requests
from bs4 import BeautifulSoup

from IPython.display import JSON

# %%
document_relationships = {
    "informatively references": {
        "desc": "Informative Reference",
        "inverse": "is informatively referenced by"
    },
    "normatively references": {
        "desc": "Normative Reference",
        "inverse": "is normatively referenced by"
    },
    "Reference": {
        "desc": "A reference found in a document which does not have split normative/informative reference sections",
        "inverse": "Referenced by"
    },
    "Possible Reference": {
        "desc": "Reference of unknown type, likely found in the text of the document",
        "inverse": "Possibly Referenced By"
    }
}

# %%
def _find_by_text(soup, tag, text):
    tags = soup.find_all(tag)
    thetag = None
    for tag in tags:
        if tag.find(text=re.compile(text)):
            thetag = tag
    return thetag

# %%
def parse_page(html):
    soup = BeautifulSoup(html, "html.parser")
    title, rfc_id = list(soup.find("h2").stripped_strings)
    last_updated = soup.find('th', string=re.compile("Last updated")).find_next("td", class_=None).text.strip()

    aka_div = _find_by_text(soup, 'div', "Also known as")
    aka = [{"uri": a.get("href"), "name": a.text} for a in aka_div.find_all("a")] if aka_div else []
    
    updates_div = _find_by_text(soup, 'div', "Updates")
    updates = [{"uri": a.get("href"), "name": a.text} for a in updates_div.find_all("a")] if updates_div else []
    
    updated_by_div = _find_by_text(soup, 'div', "Updated by")
    updated_by = [{"uri": a.get("href"), "name": a.text} for a in updated_by_div.find_all("a")] if updated_by_div else []

    obsoletes_div = _find_by_text(soup, 'div', "Obsoletes")
    obsoletes = [{"uri": a.get("href"), "name": a.text} for a in obsoletes_div.find_all("a")] if obsoletes_div else []
    
    obsoleted_by_div = _find_by_text(soup, 'div', "Obsoleted by")
    obsoleted_by = [{"uri": a.get("href"), "name": a.text} for a in obsoleted_by_div.find_all("a")] if obsoleted_by_div else []
            
    authors = [
        {"email": x.get("href"), "name": x.text}
        for x in soup.find('th', string=re.compile("Author"))
        .find_next("td", class_=None)
        .find_all("a", string=re.compile(".+"))
    ]
    
    return {
        "title": title,
        "text": _find_by_text(soup, 'a', 'plain text').get("href"),
        "pdf": _find_by_text(soup, 'a', 'pdf').get("href"),
        "html": _find_by_text(soup, 'a', 'html').get("href"),
        "label": rfc_id,
        "aka": aka,
        "last_updated": last_updated,
        "updates": updates,
        "updated_by": updated_by,
        "obsoletes": obsoletes,
        "obsoleted_by": obsoleted_by,
        "authors": authors
    }

# %%
def parse_references(html):
    result = []
    soup = BeautifulSoup(html, 'html.parser')
    try:
        rows = soup.find("h1").find_next("table").findAll('tr')[1:]
        for row in rows:
            col = row.find_all("td")
            doc = col[0].text.strip().split("\n")[0]
            status = col[2].text.strip()
            Type = col[3].text.strip()
            downref = col[4].text.strip()
            result.append({
                "name": doc,
                "status": status,
                "type": Type,
                "downref": downref
            })
    except AttributeError:
        pass
    return result

# %%
DATATRACKER_URL = "datatracker.ietf.org"
def get_datatracker_doc_info(uri, url=DATATRACKER_URL):
    r = requests.get(f"https://{url}/doc/{uri}/")
    
    main = parse_page(r.content)

    ref = requests.get(f"https://{url}/doc/{main['label'].lower().replace(' ', '')}/references/")
    refd = requests.get(f"https://{url}/doc/{main['label'].lower().replace(' ', '')}/referencedby/")
    
    main = parse_page(r.content)
    refs = parse_references(ref.content)
    refds = parse_references(refd.content)
    main["references"] = refs
    main["referenced_by"] = refds
    
    return main

# %%
docs = []
parsed = []
to_parse = ["rfc3261"]

# %%
from urllib.parse import urlparse

# %%
def parse_one(doc):
    print(f"Parsing {doc}")
    result = get_datatracker_doc_info(doc)
    related = []
    
    with open(f"files/{doc}.txt", "wb") as f:
        f.write(requests.get(result["text"]).content)
    
    for link in [*result["updates"], *result["updated_by"], *result["obsoletes"], *result["obsoleted_by"], *result["references"], *result["referenced_by"]]:
        i = link["name"].lower().replace(" ", "")
        if i not in parsed:
            related.append(i)
            
    return result, related

# %%
parse_one("rfc3261")
# Out:
# Parsing rfc3261
# ({'title': 'SIP: Session Initiation Protocol',
#   'text': 'https://www.rfc-editor.org/rfc/rfc3261.txt',
#   'pdf': 'https://www.rfc-editor.org/rfc/pdfrfc/rfc3261.txt.pdf',
#   'html': '/doc/html/rfc3261',
#   'label': 'RFC 3261',
#   'aka': [],
#   'last_updated': '2020-01-21',
#   'updates': [],
#   'updated_by': [{'uri': '/doc/rfc5393/', 'name': 'RFC 5393'},
#    {'uri': '/doc/rfc6141/', 'name': 'RFC 6141'},
#    {'uri': '/doc/rfc5630/', 'name': 'RFC 5630'},
#    {'uri': '/doc/rfc8217/', 'name': 'RFC 8217'},
#    {'uri': '/doc/rfc5954/', 'name': 'RFC 5954'},
#    {'uri': '/doc/rfc5621/', 'name': 'RFC 5621'},
#    {'uri': '/doc/rfc3853/', 'name': 'RFC 3853'},
#    {'uri': '/doc/rfc7463/', 'name': 'RFC 7463'},
#    {'uri': '/doc/rfc7462/', 'name': 'RFC 7462'},
#    {'uri': '/doc/rfc3265/', 'name': 'RFC 3265'},
#    {'uri': '/doc/rfc4320/', 'name': 'RFC 4320'},
#    {'uri': '/doc/rfc5626/', 'name': 'RFC 5626'},
#    {'uri': '/doc/rfc6026/', 'name': 'RFC 6026'},
#    {'uri': '/doc/rfc6665/', 'name': 'RFC 6665'},
#    {'uri': '/doc/rfc8996/', 'name': 'RFC 8996'},
#    {'uri': '/doc/rfc8760/', 'name': 'RFC 8760'},
#    {'uri': '/doc/rfc4916/', 'name': 'RFC 4916'},
#    {'uri': '/doc/rfc5922/', 'name': 'RFC 5922'},
#    {'uri': '/doc/rfc8898/', 'name': 'RFC 8898'},
#    {'uri': '/doc/rfc8591/', 'name': 'RFC 8591'},
#    {'uri': '/doc/rfc6878/', 'name': 'RFC 6878'}],
#   'obsoletes': [{'uri': '/doc/rfc2543/', 'name': 'RFC 2543'}],
#   'obsoleted_by': [],
#   'authors': [{'email': '/person/eve.m.schooler@intel.com',
#     'name': 'Eve Schooler'},
#    {'email': '/person/jdrosen@jdrosen.net', 'name': 'Jonathan Rosenberg'},
#    {'email': '/person/hgs@cs.columbia.edu', 'name': 'Henning Schulzrinne'},
#    {'email': '/person/alan.b.johnston@gmail.com', 'name': 'Alan Johnston'},
#    {'email': '/person/gonzalo.camarillo@ericsson.com',
#     'name': 'Gonzalo Camarillo'},
#    {'email': '/person/jon.peterson@team.neustar', 'name': 'Jon Peterson'},
#    {'email': '/person/rjsparks@nostrum.com', 'name': 'Robert Sparks'},
#    {'email': '/person/mjh@icir.org', 'name': 'Mark Handley'}],
#   'references': [{'name': 'BCP 14',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'BCP 18',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 1123',
#     'status': 'Internet Standard',
#     'type': 'Possible Reference',
#     'downref': ''},
#    {'name': 'RFC 1321',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 1750',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 1847',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 1889',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 2046',
#     'status': 'Draft Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2069',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 2076',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 2183',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2234',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2246',
#     'status': 'Historic',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 2279',
#     'status': 'Draft Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2326',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 2327',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2368',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 2396',
#     'status': 'Draft Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2401',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2426',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 2543',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 2616',
#     'status': 'Draft Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2617',
#     'status': 'Draft Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2630',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2633',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2806',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2822',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2849',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 2914',
#     'status': 'Best Current Practice',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 2960',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 2976',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3015',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3204',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3263',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3264',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3268',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 761',
#     'status': 'Historic',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 768',
#     'status': 'Internet Standard',
#     'type': 'Possible Reference',
#     'downref': ''},
#    {'name': 'STD 1',
#     'status': 'Historic',
#     'type': 'Possible Reference',
#     'downref': 'Possible Downref'},
#    {'name': 'STD 3',
#     'status': 'Internet Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'STD 6',
#     'status': 'Internet Standard',
#     'type': 'normatively references',
#     'downref': ''}],
#   'referenced_by': [{'name': 'RFC 3262',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3263',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3265',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3310',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3311',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3313',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3319',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3323',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3324',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3325',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3326',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3327',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3329',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3351',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3372',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 3388',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3398',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3427',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 3455',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3459',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3486',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3487',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3515',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3521',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3574',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3578',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3581',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3603',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3608',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3665',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 3666',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 3680',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3702',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3725',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 3764',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3824',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3840',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3841',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3842',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3853',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3856',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3857',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3858',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3880',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3891',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3892',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3893',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3903',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3910',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3911',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3944',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3959',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3960',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3966',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3968',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 3969',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 3976',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4006',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4028',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4032',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4083',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4091',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4092',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4117',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4123',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4168',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4169',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4189',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4215',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4235',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4240',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4244',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4245',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4320',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4354',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4376',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4411',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4412',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4453',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4457',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4458',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4474',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4483',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4484',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4485',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4488',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4497',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 4508',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4538',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4567',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4569',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4575',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4583',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4590',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4660',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4662',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4722',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4730',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4740',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4759',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4769',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4780',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4825',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4826',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4904',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4916',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4964',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4967',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4975',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 4976',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5025',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5027',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5031',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5049',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5079',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5168',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5194',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5245',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5263',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5264',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5359',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 5363',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5365',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5367',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5368',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5369',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5370',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5373',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5456',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5589',
#     'status': 'Best Current Practice',
#     'type': 'normatively references',
#     'downref': 'Downref'},
#    {'name': 'RFC 5627',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5629',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5631',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5806',
#     'status': 'Historic',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5853',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5898',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 5923',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 6035',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 6072',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 6080',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 6157',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 6314',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 6337',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 6446',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 6787',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 6795',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 7247',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 7315',
#     'status': 'Informational',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 7701',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 7702',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 8079',
#     'status': 'Proposed Standard',
#     'type': 'normatively references',
#     'downref': ''},
#    {'name': 'RFC 3264',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3320',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3485',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3489',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3520',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3524',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3550',
#     'status': 'Internet Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3605',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3631',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3830',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3862',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3864',
#     'status': 'Best Current Practice',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3890',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3924',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3926',
#     'status': 'Experimental',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3953',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3989',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4046',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4077',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4081',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4119',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4145',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4190',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4313',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4317',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4321',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4336',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4347',
#     'status': 'Historic',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4353',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4367',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4435',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4442',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4463',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4473',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4475',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4479',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4495',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4504',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4535',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4542',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4566',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4568',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4572',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4574',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4579',
#     'status': 'Best Current Practice',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4596',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4612',
#     'status': 'Historic',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4650',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4661',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4694',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4695',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4696',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4732',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4770',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4787',
#     'status': 'Best Current Practice',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4796',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4882',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4896',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4923',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4961',
#     'status': 'Best Current Practice',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 4977',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5012',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5039',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5057',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5058',
#     'status': 'Experimental',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5104',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5115',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5124',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5128',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5140',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5239',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5341',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5347',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5389',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5438',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5486',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5626',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5628',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5760',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5762',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5766',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5850',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 5874',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 6442',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 6726',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 7106',
#     'status': 'Informational',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 7825',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 7826',
#     'status': 'Proposed Standard',
#     'type': 'informatively references',
#     'downref': ''},
#    {'name': 'RFC 3361',
#     'status': 'Proposed Standard',
#     'type': 'Possible Reference',
#     'downref': ''},
#    {'name': 'RFC 3428',
#     'status': 'Proposed Standard',
#     'type': 'Possible Reference',
#     'downref': ''},
#    {'name': 'RFC 3794',
#     'status': 'Informational',
#     'type': 'Possible Reference',
#     'downref': ''},
#    {'name': 'RFC 3303',
#     'status': 'Informational',
#     'type': 'Reference',
#     'downref': ''},
#    {'name': 'RFC 3312',
#     'status': 'Proposed Standard',
#     'type': 'Reference',
#     'downref': ''},
#    {'name': 'RFC 3321',
#     'status': 'Proposed Standard',
#     'type': 'Reference',
#     'downref': ''},
#    {'name': 'RFC 3322',
#     'status': 'Informational',
#     'type': 'Reference',
#     'downref': ''},
#    {'name': 'RFC 3362',
#     'status': 'Proposed Standard',
#     'type': 'Reference',
#     'downref': ''},
#    {'name': 'RFC 3435',
#     'status': 'Informational',
#     'type': 'Reference',
#     'downref': ''},
#    {'name': 'RFC 3508',
#     'status': 'Informational',
#     'type': 'Reference',
#     'downref': ''},
#    {'name': 'RFC 3639',
#     'status': 'Informational',
#     'type': 'Reference',
#     'downref': ''}]},
#  ['rfc5393',
#   'rfc6141',
#   'rfc5630',
#   'rfc8217',
#   'rfc5954',
#   'rfc5621',
#   'rfc3853',
#   'rfc7463',
#   'rfc7462',
#   'rfc3265',
#   'rfc4320',
#   'rfc5626',
#   'rfc6026',
#   'rfc6665',
#   'rfc8996',
#   'rfc8760',
#   'rfc4916',
#   'rfc5922',
#   'rfc8898',
#   'rfc8591',
#   'rfc6878',
#   'rfc2543',
#   'bcp14',
#   'bcp18',
#   'rfc1123',
#   'rfc1321',
#   'rfc1750',
#   'rfc1847',
#   'rfc1889',
#   'rfc2046',
#   'rfc2069',
#   'rfc2076',
#   'rfc2183',
#   'rfc2234',
#   'rfc2246',
#   'rfc2279',
#   'rfc2326',
#   'rfc2327',
#   'rfc2368',
#   'rfc2396',
#   'rfc2401',
#   'rfc2426',
#   'rfc2543',
#   'rfc2616',
#   'rfc2617',
#   'rfc2630',
#   'rfc2633',
#   'rfc2806',
#   'rfc2822',
#   'rfc2849',
#   'rfc2914',
#   'rfc2960',
#   'rfc2976',
#   'rfc3015',
#   'rfc3204',
#   'rfc3263',
#   'rfc3264',
#   'rfc3268',
#   'rfc761',
#   'rfc768',
#   'std1',
#   'std3',
#   'std6',
#   'rfc3262',
#   'rfc3263',
#   'rfc3265',
#   'rfc3310',
#   'rfc3311',
#   'rfc3313',
#   'rfc3319',
#   'rfc3323',
#   'rfc3324',
#   'rfc3325',
#   'rfc3326',
#   'rfc3327',
#   'rfc3329',
#   'rfc3351',
#   'rfc3372',
#   'rfc3388',
#   'rfc3398',
#   'rfc3427',
#   'rfc3455',
#   'rfc3459',
#   'rfc3486',
#   'rfc3487',
#   'rfc3515',
#   'rfc3521',
#   'rfc3574',
#   'rfc3578',
#   'rfc3581',
#   'rfc3603',
#   'rfc3608',
#   'rfc3665',
#   'rfc3666',
#   'rfc3680',
#   'rfc3702',
#   'rfc3725',
#   'rfc3764',
#   'rfc3824',
#   'rfc3840',
#   'rfc3841',
#   'rfc3842',
#   'rfc3853',
#   'rfc3856',
#   'rfc3857',
#   'rfc3858',
#   'rfc3880',
#   'rfc3891',
#   'rfc3892',
#   'rfc3893',
#   'rfc3903',
#   'rfc3910',
#   'rfc3911',
#   'rfc3944',
#   'rfc3959',
#   'rfc3960',
#   'rfc3966',
#   'rfc3968',
#   'rfc3969',
#   'rfc3976',
#   'rfc4006',
#   'rfc4028',
#   'rfc4032',
#   'rfc4083',
#   'rfc4091',
#   'rfc4092',
#   'rfc4117',
#   'rfc4123',
#   'rfc4168',
#   'rfc4169',
#   'rfc4189',
#   'rfc4215',
#   'rfc4235',
#   'rfc4240',
#   'rfc4244',
#   'rfc4245',
#   'rfc4320',
#   'rfc4354',
#   'rfc4376',
#   'rfc4411',
#   'rfc4412',
#   'rfc4453',
#   'rfc4457',
#   'rfc4458',
#   'rfc4474',
#   'rfc4483',
#   'rfc4484',
#   'rfc4485',
#   'rfc4488',
#   'rfc4497',
#   'rfc4508',
#   'rfc4538',
#   'rfc4567',
#   'rfc4569',
#   'rfc4575',
#   'rfc4583',
#   'rfc4590',
#   'rfc4660',
#   'rfc4662',
#   'rfc4722',
#   'rfc4730',
#   'rfc4740',
#   'rfc4759',
#   'rfc4769',
#   'rfc4780',
#   'rfc4825',
#   'rfc4826',
#   'rfc4904',
#   'rfc4916',
#   'rfc4964',
#   'rfc4967',
#   'rfc4975',
#   'rfc4976',
#   'rfc5025',
#   'rfc5027',
#   'rfc5031',
#   'rfc5049',
#   'rfc5079',
#   'rfc5168',
#   'rfc5194',
#   'rfc5245',
#   'rfc5263',
#   'rfc5264',
#   'rfc5359',
#   'rfc5363',
#   'rfc5365',
#   'rfc5367',
#   'rfc5368',
#   'rfc5369',
#   'rfc5370',
#   'rfc5373',
#   'rfc5456',
#   'rfc5589',
#   'rfc5627',
#   'rfc5629',
#   'rfc5631',
#   'rfc5806',
#   'rfc5853',
#   'rfc5898',
#   'rfc5923',
#   'rfc6035',
#   'rfc6072',
#   'rfc6080',
#   'rfc6157',
#   'rfc6314',
#   'rfc6337',
#   'rfc6446',
#   'rfc6787',
#   'rfc6795',
#   'rfc7247',
#   'rfc7315',
#   'rfc7701',
#   'rfc7702',
#   'rfc8079',
#   'rfc3264',
#   'rfc3320',
#   'rfc3485',
#   'rfc3489',
#   'rfc3520',
#   'rfc3524',
#   'rfc3550',
#   'rfc3605',
#   'rfc3631',
#   'rfc3830',
#   'rfc3862',
#   'rfc3864',
#   'rfc3890',
#   'rfc3924',
#   'rfc3926',
#   'rfc3953',
#   'rfc3989',
#   'rfc4046',
#   'rfc4077',
#   'rfc4081',
#   'rfc4119',
#   'rfc4145',
#   'rfc4190',
#   'rfc4313',
#   'rfc4317',
#   'rfc4321',
#   'rfc4336',
#   'rfc4347',
#   'rfc4353',
#   'rfc4367',
#   'rfc4435',
#   'rfc4442',
#   'rfc4463',
#   'rfc4473',
#   'rfc4475',
#   'rfc4479',
#   'rfc4495',
#   'rfc4504',
#   'rfc4535',
#   'rfc4542',
#   'rfc4566',
#   'rfc4568',
#   'rfc4572',
#   'rfc4574',
#   'rfc4579',
#   'rfc4596',
#   'rfc4612',
#   'rfc4650',
#   'rfc4661',
#   'rfc4694',
#   'rfc4695',
#   'rfc4696',
#   'rfc4732',
#   'rfc4770',
#   'rfc4787',
#   'rfc4796',
#   'rfc4882',
#   'rfc4896',
#   'rfc4923',
#   'rfc4961',
#   'rfc4977',
#   'rfc5012',
#   'rfc5039',
#   'rfc5057',
#   'rfc5058',
#   'rfc5104',
#   'rfc5115',
#   'rfc5124',
#   'rfc5128',
#   'rfc5140',
#   'rfc5239',
#   'rfc5341',
#   'rfc5347',
#   'rfc5389',
#   'rfc5438',
#   'rfc5486',
#   'rfc5626',
#   'rfc5628',
#   'rfc5760',
#   'rfc5762',
#   'rfc5766',
#   'rfc5850',
#   'rfc5874',
#   'rfc6442',
#   'rfc6726',
#   'rfc7106',
#   'rfc7825',
#   'rfc7826',
#   'rfc3361',
#   'rfc3428',
#   'rfc3794',
#   'rfc3303',
#   'rfc3312',
#   'rfc3321',
#   'rfc3322',
#   'rfc3362',
#   'rfc3435',
#   'rfc3508',
#   'rfc3639'])

# %%
from multiprocessing.dummy import Pool as ThreadPool

def collect_data_about_rfc(name):
    json_result = {}
    center_rfc, related = parse_one(name)
    json_result[name] = center_rfc
    
    pool = ThreadPool(20)
    results = pool.map(parse_one, related)
    pool.close()
    pool.join()
    
    json_result.update(dict(zip(related, [r[0] for r in results])))
    
    with open("data.json", "w+") as f:
        json.dump(json_result, f)

# %%
collect_data_about_rfc("rfc3261")
# Out:
# Parsing rfc3261
# Parsing rfc5393
# Parsing rfc5954
# Parsing rfc7462
# Parsing rfc6026
# Parsing rfc4916
# Parsing rfc6878
# Parsing rfc1123
# Parsing rfc1889
# Parsing rfc2183
# Parsing rfc2326
# Parsing rfc2401
# Parsing rfc2617
# Parsing rfc2822
# Parsing rfc2976
# Parsing rfc3264
# Parsing std1
# Parsing rfc3263
# Parsing rfc3313
# Parsing rfc3325
# Parsing rfc3351
# Parsing rfc3372
# Parsing rfc3015
# Parsing rfc2543
# Parsing rfc6665
# Parsing rfc6141
# Parsing rfc5922
# Parsing rfc5621
# Parsing rfc3319
# Parsing rfc3265
# Parsing rfc3326
# Parsing rfc3265
# Parsing rfc2234
# Parsing rfc2630
# Parsing rfc2327
# Parsing rfc2046
# Parsing rfc2849
# Parsing rfc3388
# Parsing rfc5630
# Parsing rfc3204
# Parsing rfc3323
# Parsing rfc8996
# Parsing rfc3327
# Parsing rfc8898
# Parsing rfc3853
# Parsing rfc2426
# Parsing rfc3268
# Parsing rfc4320
# Parsing bcp14
# Parsing rfc2633
# Parsing std3
# Parsing rfc1321
# Parsing rfc2914
# Parsing rfc3310
# Parsing rfc2368
# Parsing rfc3398
# Parsing rfc2246
# Parsing rfc7463
# Parsing rfc8217
# Parsing rfc3329
# Parsing rfc3263
# Parsing rfc761
# Parsing rfc8591
# Parsing rfc2543
# Parsing rfc2069
# Parsing rfc3324
# Parsing rfc5626
# Parsing rfc3311
# Parsing rfc2806
# Parsing rfc2396
# Parsing rfc2960
# Parsing rfc3427
# Parsing rfc3487
# Parsing rfc8760
# Parsing rfc3578
# Parsing rfc3665
# Parsing rfc768
# Parsing rfc3725
# Parsing rfc2076
# Parsing rfc3841
# Parsing rfc1750
# Parsing rfc3857
# Parsing rfc3892
# Parsing rfc3911
# Parsing rfc2616
# Parsing rfc2279
# Parsing rfc3966
# Parsing std6
# Parsing rfc3515
# Parsing rfc3455
# Parsing rfc3581
# Parsing rfc4006
# Parsing rfc3666
# Parsing rfc4091
# Parsing rfc4168
# Parsing rfc4235
# Parsing rfc3858
# Parsing rfc3764
# Parsing rfc3842
# Parsing rfc3893
# Parsing bcp18Parsing rfc3944
#
# Parsing rfc1847
# Parsing rfc3968
# Parsing rfc3459
# Parsing rfc3521
# Parsing rfc3603
# Parsing rfc4320
# Parsing rfc4412
# Parsing rfc4028
# Parsing rfc4092
# Parsing rfc4169
# Parsing rfc3680
# Parsing rfc3824
# Parsing rfc3880
# Parsing rfc4240
# Parsing rfc3853
# Parsing rfc3903
# Parsing rfc3959
# Parsing rfc3262
# Parsing rfc4474
# Parsing rfc3608
# Parsing rfc4354
# Parsing rfc3574
# Parsing rfc3969
# Parsing rfc4488
# Parsing rfc3486
# Parsing rfc4453
# Parsing rfc4032
# Parsing rfc4189
# Parsing rfc4117
# Parsing rfc3891
# Parsing rfc3702
# Parsing rfc4567
# Parsing rfc3840
# Parsing rfc3856
# Parsing rfc4244
# Parsing rfc3910
# Parsing rfc3960
# Parsing rfc4590
# Parsing rfc4376
# Parsing rfc4730
# Parsing rfc4780
# Parsing rfc4497
# Parsing rfc4483
# Parsing rfc3976
# Parsing rfc4457
# Parsing rfc4916
# Parsing rfc4083
# Parsing rfc4976
# Parsing rfc4215
# Parsing rfc4123
# Parsing rfc5049
# Parsing rfc5245
# Parsing rfc4569
# Parsing rfc4245
# Parsing rfc5363
# Parsing rfc5369
# Parsing rfc5589
# Parsing rfc4411
# Parsing rfc4660
# Parsing rfc4740
# Parsing rfc4825
# Parsing rfc4458
# Parsing rfc5806
# Parsing rfc6035
# Parsing rfc4964
# Parsing rfc4508
# Parsing rfc4484
# Parsing rfc6314
# Parsing rfc6795
# Parsing rfc5025
# Parsing rfc7702Parsing rfc5079
#
# Parsing rfc4575
# Parsing rfc5370
# Parsing rfc5365
# Parsing rfc3485
# Parsing rfc5627
# Parsing rfc4662
# Parsing rfc3550
# Parsing rfc4759
# Parsing rfc5853
# Parsing rfc5263
# Parsing rfc4826
# Parsing rfc4485
# Parsing rfc6072
# Parsing rfc4967
# Parsing rfc7247
# Parsing rfc4538
# Parsing rfc6337
# Parsing rfc5168
# Parsing rfc5027
# Parsing rfc5373
# Parsing rfc5367
# Parsing rfc8079
# Parsing rfc4583
# Parsing rfc3489
# Parsing rfc4722
# Parsing rfc4769
# Parsing rfc5629
# Parsing rfc5264
# Parsing rfc5898
# Parsing rfc4975
# Parsing rfc3862
# Parsing rfc3926
# Parsing rfc6080
# Parsing rfc6446
# Parsing rfc7315
# Parsing rfc5194
# Parsing rfc4904
# Parsing rfc5031
# Parsing rfc5456
# Parsing rfc5368
# Parsing rfc4077
# Parsing rfc3264
# Parsing rfc3520
# Parsing rfc4190
# Parsing rfc4336
# Parsing rfc5359
# Parsing rfc5631
# Parsing rfc5923
# Parsing rfc3953
# Parsing rfc4435
# Parsing rfc6787
# Parsing rfc4475
# Parsing rfc7701
# Parsing rfc4535
# Parsing rfc3864
# Parsing rfc6157
# Parsing rfc4572
# Parsing rfc3605
# Parsing rfc4081
# Parsing rfc4612
# Parsing rfc4695
# Parsing rfc4347
# Parsing rfc4787
# Parsing rfc4313
# Parsing rfc4923
# Parsing rfc5039
# Parsing rfc3524
# Parsing rfc3989
# Parsing rfc4442
# Parsing rfc5115
# Parsing rfc4650
# Parsing rfc3631
# Parsing rfc4479
# Parsing rfc4574
# Parsing rfc4119
# Parsing rfc5239
# Parsing rfc3320
# Parsing rfc4542
# Parsing rfc5438
# Parsing rfc4696
# Parsing rfc5760
# Parsing rfc3890
# Parsing rfc4317
# Parsing rfc4353
# Parsing rfc5057
# Parsing rfc4961
# Parsing rfc4463
# Parsing rfc4046
# Parsing rfc5124
# Parsing rfc4579
# Parsing rfc4661
# Parsing rfc4796
# Parsing rfc5341
# Parsing rfc5486
# Parsing rfc4495
# Parsing rfc4566
# Parsing rfc4732
# Parsing rfc5874
# Parsing rfc4145
# Parsing rfc3830
# Parsing rfc4321
# Parsing rfc3924
# Parsing rfc5058
# Parsing rfc4367
# Parsing rfc4473
# Parsing rfc5762
# Parsing rfc4977
# Parsing rfc7825
# Parsing rfc5128
# Parsing rfc4694
# Parsing rfc5626
# Parsing rfc4882
# Parsing rfc5347
# Parsing rfc4596
# Parsing rfc4504
# Parsing rfc6442
# Parsing rfc3794
# Parsing rfc3322
# Parsing rfc4770
# Parsing rfc3639
# Parsing rfc5104
# Parsing rfc5012
# Parsing rfc7826
# Parsing rfc5766
# Parsing rfc5140
# Parsing rfc4896
# Parsing rfc5389
# Parsing rfc3362
# Parsing rfc6726
# Parsing rfc5628
# Parsing rfc4568
# Parsing rfc3303
# Parsing rfc3435
# Parsing rfc5850
# Parsing rfc3361
# Parsing rfc7106
# Parsing rfc3312
# Parsing rfc3428
# Parsing rfc3508
# Parsing rfc3321
